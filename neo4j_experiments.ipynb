# %% [markdown]
# ## 1. Supply Chain mapping with neo4j

# %%
from xbbg import blp
import neo4j
import pandas as pd
import numpy as np
from neo4j import GraphDatabase
import nxneo4j as nnx
import networkx as nx
from typing import Union, Tuple, List, Optional, Set
from typing import List, Tuple, Iterable, Dict
from concurrent.futures import ThreadPoolExecutor, as_completed
import logging
import os
from pathlib import Path


uri = r"bolt://localhost:7687/"
user = "neo4j"
LOGPATH = Path("./log/")
if not LOGPATH.exists():
    LOGPATH.mkdir()
LOGFILE = LOGPATH.joinpath("log.txt")
logging.basicConfig(filename=LOGFILE.as_posix())

METADATA_FLDS = ['name', 'short_name', 'security_name', 'long_comp_name',
    'name_chinese_traditional', 'name_kanji', 'industry_sector',
    'industry_group', 'industry_subgroup', 
    'name_chinese_simplified', 'ud_em_sector', 'ud_research_note_date',
    'ud_msci_market_classification', 'ud_water_sector', 'ud_esg_score',
    'pct_independent_directors', 'ud_esg_note_date',
    'gics_sector_name', 'gics_industry_group_name', 'gics_iindustry_name', 
    'gics_sub_industry_name', 'cur_adj_mkt_cap', 
    'best_cur_ev_to_ebitda', 'best_pe_ratio', 'est_pe_nxt_yr', 
    'est_pe_cur_yr', 'five_yr_avg_price_earnings', 'best_px_sales_ratio',
    'fcf_yield_with_cur_entp_val', 'px_to_book_ratio',
    'crncy_adj_mkt_cap'
    ]

DEFAULT_NNX_CONFIG = {"node_label": "Company",
    "relationship_type": "supply",
    }

class Neo4jQueries:
    def create_database(driver, database_name: str='neo4j') -> None:
        with driver.session(default_access_mode=neo4j.READ_ACCESS) as session:
            session.run(f"CREATE {database_name} IF NOT EXISTS")
        
    def __init__(self, driver: GraphDatabase.driver, database_name: str=None):
        self.driver = driver
        if database_name:
            self.create_graph(database_name=database_name)

    def add_node():
        raise NotImplementedError

    

class SupplyChainRelation:

    @staticmethod
    def _metadata(tickers: Iterable[str], max_len: int=100, max_workers: int=16) -> pd.DataFrame:
        """get the metadata of the tickers
        :param tickers: iterable of the tickers
        :param max_size: max no of tickers to be sent to the API at once
        :param max_workers: max workers for multi threaded calculation
        """
        if len(tickers) <= max_len:
            res = blp.bdp(tickers, flds=METADATA_FLDS)
        else:
            chunks = [tickers[i: i+max_len] for i in range(0, len(tickers), max_len)]
            if max_workers:
                with ThreadPoolExecutor(max_workers=max_workers) as executor:
                    futures = [executor.submit(blp.bdp, chunk, flds=METADATA_FLDS) for chunk in chunks]
                    res = pd.concat([future.result() for future in as_completed(futures)])
            else:
                res = pd.concat([blp.bdp(chunk, flds=METADATA_FLDS) for chunk in chunks])
        return res

    def __init__(self, 
        tickerlist: Optional[Iterable[str]]=None, 
        max_workers: int=16,
        neo4j_config: Optional[Dict[str, str]]=None):
        self.tickerlist = tickerlist
        self.__all__ = ['get_cutomers', 'get_suppliers'] # TODO - update this when done
        self.max_workers = max_workers
        self._driver = None
        if neo4j_config:
            self._driver = GraphDatabase.driver(uri=neo4j_config.get('uri'),
                auth=(neo4j_config.get('username', 'neo4j'), 
                    neo4j_config.get('password')))

    @property
    def driver(self):
        return self._driver

    @driver.setter
    def driver(self, new_driver: GraphDatabase):
        self._driver = new_driver

    @staticmethod
    def _customer_list(ticker: str, 
        top_k: int=50,
        ignore_error: bool=False) -> pd.DataFrame:
        """returns dataframe of the customers
        :param ticker: takes the BBG ID or BBG ticker
        :param top_k: top k relations to be returned
        """
        try:
            df = blp.bds(ticker,"supply_chain_customers",
                        supply_chain_sum_count_override=top_k)
            df.columns = ['partner_ticker']
        except Exception as e:
            if ignore_error:
                logging.error(f"The following happened while calling _rel_amount({ticker}, {top_k}):\n{e}\n")
                pass
            else:
                raise e
        return df
    
    @staticmethod
    def _supplier_list(ticker: str, 
        top_k: int=50,
        ignore_error: bool=False) -> pd.DataFrame:
        """returns dataframe of the suppliers
        :param ticker: takes the BBG ID or BBG ticker
        :param top_k: top k relations to be returned
        """
        try:
            df = blp.bds(ticker, "supply_chain_suppliers",
                        supply_chain_sum_count_override=top_k)
            df.columns = ['partner_ticker']
        except Exception as e:
            if ignore_error:
                logging.error(f"The following happened while calling _rel_amount({ticker}, {top_k}):\n{e}\n")
                pass
            else:
                raise e
        return df
    
    @staticmethod
    def _rel_amount(head: str, tail: str, relationship: str='C',
        ignore_error: bool=True):
        """
        :param head: head of the relation
        :param tail: tail of the relation
        :param relationship: takes 'C' (customer) or 'S' (supplier). 
        
        Note:
            Order of head and tail matters. (head, tail, relationship) implies
            that tail has_relationship with head. e.g. A, B, 'C' means B is 
            customer of A. Reversing A and B will result in returning None
        """
        try:
            tmp = blp.bdp(head, "RELATIONSHIP_AMOUNT",
                        relationship_override=relationship,
                        quantified_override='Y',
                        eqy_fund_crncy='USD',
                        related_company_override=tail)
            tmp.index = [tail]
            return tmp
        except Exception as e:
            if ignore_error:
                logging.error(f"The following happened while calling _rel_amount({head}, {tail}, {relationship}):\n{e}\n")
                pass
            else:
                raise e

    @staticmethod
    def _rel_perc(head: str, tail: str, 
        relationship: str='C',
        ignore_error: bool=False):
        """
        :param head: head of the relation
        :param tail: tail of the relation
        :param relationship: takes 'C' (customer) or 'S' (supplier). 
        
        Note:
            Order of head and tail matters. (head, tail, relationship) implies
            that tail has_relationship with head. e.g. A, B, 'C' means B is 
            customer of A. Reversing A and B will result in returning None
        """
        try:
            tmp = blp.bdp(head, "SUPPLY_CHAIN_REVENUE_PERCENTAGE",
                        relationship_override=relationship,
                        quantified_override='Y',
                        eqy_fund_crncy='USD',
                        related_company_override=tail)
            tmp.index = [tail]
            return tmp
        except Exception as e:
            if ignore_error:
                logging.error(f"The following happened while calling _rel_amount({head}, {tail}, {relationship}):\n{e}\n")
                pass
            else:
                raise e
        
    def __contribution(self,
        ticker: str, 
        top_k: int=50, 
        relationship: str='C',
        return_type: str='amount') -> pd.DataFrame:
        """get contribution by customer
        :param ticker: ticker to get information about
        :param top_k: max number of relations to be returned
        :param relationship: takes 'C' - customer or 'S' - supplier
        :param return_type: str, takes 'amount' and 'percent'
        """
        tmps = []
        if relationship in ['C', 'customers']:
            partners = self._customer_list(ticker, top_k=top_k).partner_ticker
            if return_type in ['amount']:
                with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
                    futures = [executor.submit(self._rel_amount, ticker, p, relationship) 
                        for p in partners]
            elif return_type in ['percent']:
                with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
                    futures = [executor.submit(self._rel_perc, ticker, p, relationship) 
                        for p in partners]
            else: raise NotImplementedError
            
        elif relationship in ['S', 'suppliers']:
            partners = self._supplier_list(ticker, top_k=top_k).partner_ticker
            if return_type in ['amount']:
                with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
                    futures = [executor.submit(self._rel_amount, ticker, p, relationship) 
                        for p in partners]
            elif return_type in ['percent']:
                with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
                    futures = [executor.submit(self._rel_perc, ticker, p, relationship) 
                        for p in partners]
            else: raise NotImplementedError
        else: raise NotImplementedError
        tmps = [future.result() for future in as_completed(futures)]
        df = pd.concat(tmps)
        return df

    def _customer_contribution(self, 
        ticker: str, 
        top_k: int=50, 
        return_type: str='amount') -> pd.DataFrame:
        """get contribution by customer
        :param ticker: ticker to get information about
        :param top_k: max number of relations to be returned
        :param return_type: str, takes 'amount' and 'percent'
        """
        return self.__contribution(ticker=ticker, top_k=top_k, 
            relationship='C', 
            return_type=return_type)

    @classmethod
    def get_customer_contribution(cls, ticker: str, 
        top_k: int=50, 
        return_type='amount', **kwargs):
        """classmethod version of _customer_contribution"""
        return cls(**kwargs)._customer_contribution(
            ticker, top_k=top_k, return_type=return_type)

    def _supplier_contribution(self, 
        ticker: str, 
        top_k: int=50, 
        return_type: str='amount') -> pd.DataFrame:
        """get contribution by customer
        :param ticker: ticker to get information about
        :param top_k: max number of relations to be returned
        :param return_type: str, takes 'amount' and 'percent'
        """
        return self.__contribution(ticker=ticker, top_k=top_k, 
            relationship='S', 
            return_type=return_type)

    @classmethod
    def get_supplier_contribution(cls, ticker: str, 
        top_k: int=50, 
        return_type='amount', **kwargs):
        """classmethod version of _supplier_contribution"""
        return cls(**kwargs)._supplier_contribution(
            ticker, top_k=top_k, return_type=return_type)

    def __add_ticker_partners(self, ticker: str, 
        edges: List[Dict], 
        top_k: int=50,
        nodes: Set=set(),
        verbose: bool=False,
        ignore_error: bool=True):
        """add relations to graph and return new nodes
        :param ticker: ticker to be processed
        :param G: graph object
        :param top_k: top_k relations to be returned
        :param nodes: unique nodes in the graph
        :param verbose: print which ticker is being processed
        """
        nodes.add(ticker)
        if verbose: print(ticker)
        suppliers_amount = self._supplier_contribution(ticker, top_k=top_k).reset_index()
        suppliers_percent = self._supplier_contribution(ticker, top_k=top_k, return_type='percent').reset_index()
        suppliers = suppliers_amount.merge(suppliers_percent, on=['index']).set_index('index')
        for supplier, row in suppliers.iterrows():
            try:
                if verbose: print(ticker, supplier)
                nodes.add(supplier)
                edges.append(dict(node1=supplier, node2=ticker, 
                    type='supply', label='supply',
                    source='Bloomberg',
                    percent_of_supplier=row.supply_chain_revenue_percentage,
                    amount=row.relationship_amount))
            except Exception as e:
                if ignore_error:
                    logging.error(e)
                    pass
                else:
                    raise e
        customers_amount = self._customer_contribution(ticker, top_k=top_k).reset_index()
        customers_percent = self._customer_contribution(ticker, top_k=top_k, return_type='percent').reset_index()
        customers = customers_amount.merge(customers_percent, on=['index']).set_index('index')
        for customer, row in customers.iterrows():
            if verbose: print(ticker, customer)
            try:
                nodes.add(customer)
                edges.append(dict(node1=ticker, node2=customer, 
                    type='supply', label='supply',
                    source='Bloomberg',
                    percent_of_supplier=row.supply_chain_revenue_percentage,
                    amount=row.relationship_amount))
            except Exception as e:
                if ignore_error:
                    logging.error(e)
                    pass
                else:
                    raise e
        
        return edges, nodes

    def get_graph(self, top_k=50, 
        max_workers: int=16,
        with_metadata: bool=True,
        verbose: bool=True,
        to_neo4j: bool=False,
        ignore_error: bool=True,
        nxneo4j_config: Dict=DEFAULT_NNX_CONFIG):
        """returns a graph object of the supply chain relationship
        :param useAmount: is True, will use the amount of the relationship as 
            weight of edges
        :param top_k: Max # of partners retrieves. 50 by default
        """
        
        if to_neo4j:
            G = nnx.DiGraph(self.driver, config=nxneo4j_config) 
        else:
            G = nx.DiGraph()
        nodes, edges = set(), list()
        
        if max_workers:
            with ThreadPoolExecutor(max_workers=max_workers) as executor:
                futures = [executor.submit(self.__add_ticker_partners, ticker, edges, top_k, nodes, verbose, ignore_error)
                    for ticker in self.tickerlist]
                for future in as_completed(futures):
                    try:
                        new_edges, new_nodes = future.result()
                        nodes.add(new_nodes)
                        edges.append(new_edges)
                    except Exception as e:
                        if ignore_error: 
                            logging.error(f"""The following error happened while calling get_graph(top_k={top_k}, with_metadata={with_metadata}, verbose={verbose}, to_neo4j={to_neo4j}, ignore_error={ignore_error}))
                            {e}
                            """)
            
                        else: raise e
        else:
            for ticker in self.tickerlist:
                try:
                    edges, nodes = self.__add_ticker_partners(ticker, edges, top_k, nodes, verbose, ignore_error)
                except Exception as e:
                    if ignore_error: 
                        logging.error(f"""The following error happened while calling get_graph(top_k={top_k}, with_metadata={with_metadata}, verbose={verbose}, to_neo4j={to_neo4j}, ignore_error={ignore_error}))
                        {e}
                        """)
            
                    else: raise e
        metadata = self._metadata(list(nodes))
        for node, row in metadata.iterrows():
            G.add_node(node, node_label='Company', labels=['Company', row.industry_sector, row.industry_group, row.industry_subgroup], 
                data_source='Bloomberg', **row.to_dict())
        for edge in edges:
            G.add_edge(data_source='Bloomberg', relationship_type='supply', 
                name='supply', **edge)
        return G, metadata

# %%
tickers = np.unique([f"{t} Equity" for t in 
    blp.bds("SOX Index", "indx_members").member_ticker_and_exchange_code] + \
        [f"{t} Equity" for t in 
    blp.bds("S5INFT Index", "indx_members").member_ticker_and_exchange_code])

# %%
sc = SupplyChainRelation(tickers,
    neo4j_config={'uri': r"bolt://localhost:7687", 
        "password": input("password"),
        "username": "neo4j"})
G, metadata = sc.get_graph(verbose=True, max_workers=0, to_neo4j=True)
# Out:
# AAPL UW Equity
# AAPL UW Equity 2382 TT Equity
# AAPL UW Equity 2330 TT Equity
# AAPL UW Equity 005930 KS Equity
# AAPL UW Equity 4958 TT Equity
# AAPL UW Equity SWKS US Equity
# AAPL UW Equity 3711 TT Equity
# AAPL UW Equity 2317 TT Equity
# AAPL UW Equity QCOM US Equity
# AAPL UW Equity 034220 KS Equity
# AAPL UW Equity 011070 KS Equity
# AAPL UW Equity 002475 CH Equity
# AAPL UW Equity 4938 TT Equity
# AAPL UW Equity STM FP Equity
# AAPL UW Equity 000660 KS Equity
# AAPL UW Equity 300433 CH Equity
# AAPL UW Equity AVGO US Equity
# AAPL UW Equity 002241 CH Equity
# AAPL UW Equity 6753 JP Equity
# AAPL UW Equity 2324 TT Equity
# AAPL UW Equity JBL US Equity
# AAPL UW Equity BT/A LN Equity
# AAPL UW Equity T CN Equity
# AAPL UW Equity 9984 JP Equity
# AAPL UW Equity 9433 JP Equity
# AAPL UW Equity TEF SM Equity
# AAPL UW Equity T US Equity
# AAPL UW Equity VOD LN Equity
# AAPL UW Equity ORA FP Equity
# AAPL UW Equity CEC GR Equity
# AAPL UW Equity RCI/B CN Equity
# AAPL UW Equity 762 HK Equity
# AAPL UW Equity TMUS US Equity
# AAPL UW Equity EN FP Equity
# AAPL UW Equity ERAA IJ Equity
# AAPL UW Equity BBY US Equity
# AAPL UW Equity VZ US Equity
# AAPL UW Equity 941 HK Equity
# AAPL UW Equity 728 HK Equity
# AAPL UW Equity BCE CN Equity
# AAPL UW Equity DTE GR Equity
# ACN UN Equity
# ACN UN Equity TEMN SW Equity
# ACN UN Equity JBGS US Equity
# ACN UN Equity CRES IM Equity
# ACN UN Equity NTAP US Equity
# ACN UN Equity 1971448D LN Equity
# ACN UN Equity MHH US Equity
# ACN UN Equity CAI AV Equity
# ACN UN Equity 0731989D US Equity
# ACN UN Equity HLIT US Equity
# ACN UN Equity ADBE US Equity
# ACN UN Equity 1023727D US Equity
# ACN UN Equity BALI IJ Equity
# ACN UN Equity DLN LN Equity
# ACN UN Equity ORCL US Equity
# ACN UN Equity 1502052D US Equity
# ACN UN Equity HPE US Equity
# ACN UN Equity IBM US Equity
# ACN UN Equity PEGA US Equity
# ACN UN Equity 354 HK Equity
# ACN UN Equity AUB FP Equity
# ACN UN Equity 0219738Z US Equity
# ACN UN Equity 0219250Z US Equity
# ACN UN Equity 0251349Z US Equity
# ACN UN Equity 002407 CH Equity
# ACN UN Equity 0217762Z US Equity
# ACN UN Equity 0242416Z US Equity
# ACN UN Equity 0238221Z US Equity
# ACN UN Equity 0238189Z US Equity
# ACN UN Equity 000792 CH Equity
# ACN UN Equity 0154837D US Equity
# ACN UN Equity 0228369Z US Equity
# ACN UN Equity 0247137Z US Equity
# ACN UN Equity 0233205Z US Equity
# ACN UN Equity 3352Z US Equity
# ACN UN Equity 0219834Z US Equity
# ACN UN Equity 0229544Z US Equity
# ACN UN Equity 0228856Z US Equity
# ACN UN Equity 0228149Z US Equity
# ACN UN Equity SCC TB Equity
# ACN UN Equity 0219354Z US Equity
# ADBE UW Equity
# ADBE UW Equity DLN LN Equity
# ADBE UW Equity 300369 CH Equity
# ADBE UW Equity 5091Z US Equity
# ADBE UW Equity NVDA US Equity
# ADBE UW Equity 9501 JP Equity
# ADBE UW Equity 0218485D US Equity
# ADBE UW Equity ALEMK BB Equity
# ADBE UW Equity 7602163Z US Equity
# ADBE UW Equity 752 HK Equity
# ADBE UW Equity KRC US Equity
# ADBE UW Equity ASKN GR Equity
# ADBE UW Equity ALBFR FP Equity
# ADBE UW Equity HPE US Equity
# ADBE UW Equity STX US Equity
# ADBE UW Equity 033230 KS Equity
# ADBE UW Equity 3788 JP Equity
# ADBE UW Equity 0747436D CN Equity
# ADBE UW Equity 1554612D US Equity
# ADBE UW Equity AKAM US Equity
# ADBE UW Equity 2170 JP Equity
# ADBE UW Equity DTE GR Equity
# ADBE UW Equity IBM US Equity
# ADBE UW Equity WMT US Equity
# ADBE UW Equity CDW US Equity
# ADBE UW Equity 992 HK Equity
# ADBE UW Equity DELL US Equity
# ADBE UW Equity HPQ US Equity
# ADBE UW Equity CVS US Equity
# ADBE UW Equity 005930 KS Equity
# ADBE UW Equity UNH US Equity
# ADBE UW Equity NSIT US Equity
# ADBE UW Equity AAPL US Equity
# ADBE UW Equity 6758 JP Equity
# ADBE UW Equity SNX US Equity
# ADBE UW Equity CAP FP Equity
# ADBE UW Equity BBY US Equity
# ADBE UW Equity AMZN US Equity
# ADBE UW Equity CMCSA US Equity
# ADBE UW Equity ORA FP Equity
# ADBE UW Equity EDF FP Equity
# ADI UW Equity
# ADI UW Equity 8035 JP Equity
# ADI UW Equity 2330 TT Equity
# ADI UW Equity INTT US Equity
# ADI UW Equity 600584 CH Equity
# ADI UW Equity 9501 JP Equity
# ADI UW Equity PTC US Equity
# ADI UW Equity COHU US Equity
# ADI UW Equity KEYS US Equity
# ADI UW Equity 2449 TT Equity
# ADI UW Equity UTL US Equity
# ADI UW Equity MTRN US Equity
# ADI UW Equity ADBE US Equity
# ADI UW Equity TER US Equity
# ADI UW Equity TSEM IT Equity
# ADI UW Equity 2303 TT Equity
# ADI UW Equity PCG US Equity
# ADI UW Equity KLAC US Equity
# ADI UW Equity SYPR US Equity
# ADI UW Equity 3711 TT Equity
# ADI UW Equity EIX US Equity
# ADI UW Equity 7609 JP Equity
# ADI UW Equity ROK US Equity
# ADI UW Equity ARW US Equity
# ADI UW Equity BRK/A US Equity
# ADI UW Equity RBOS GR Equity
# ADI UW Equity 6189 TT Equity
# ADI UW Equity 3156 JP Equity
# ADI UW Equity 6645 JP Equity
# ADI UW Equity 3036 TT Equity
# ADI UW Equity NATI US Equity
# ADI UW Equity SERL SP Equity
# ADI UW Equity AAPL US Equity
# ADI UW Equity 3702 TT Equity
# ADI UW Equity 3528 TT Equity
# ADI UW Equity 3132 JP Equity
# ADI UW Equity KMCACZ CH Equity
# ADI UW Equity EXLP SP Equity
# ADI UW Equity BABA US Equity
# ADI UW Equity 2760 JP Equity
# ADI UW Equity 700 HK Equity
# ADP UW Equity
# ADP UW Equity ALUMS FP Equity
# ADP UW Equity SWCH US Equity
# ADP UW Equity CRWD US Equity
# ADP UW Equity AEYE US Equity
# ADP UW Equity 1437010D US Equity
# ADP UW Equity GOOD US Equity
# ADP UW Equity 036090 KS Equity
# ADP UW Equity 1943382D US Equity
# ADP UW Equity 1984541D US Equity
# ADP UW Equity 1714624D FP Equity
# ADP UW Equity OPI US Equity
# ADP UW Equity 9990711D US Equity
# ADP UW Equity 1703269D CN Equity
# ADP UW Equity TNT-U CN Equity
# ADP UW Equity ZBRA US Equity
# ADP UW Equity 1085090D US Equity
# ADP UW Equity CUZ US Equity
# ADP UW Equity AAD GR Equity
# ADP UW Equity GWI LN Equity
# ADP UW Equity HQY US Equity
# ADP UW Equity LQDT US Equity
# ADP UW Equity MRCY US Equity
# ADP UW Equity HRI US Equity
# ADP UW Equity JASNQ US Equity
# ADP UW Equity PRMW CN Equity
# ADP UW Equity SGE LN Equity
# ADSK UW Equity
# ADSK UW Equity AAT US Equity
# ADSK UW Equity NVDA US Equity
# ADSK UW Equity 1866606D UH Equity
# ADSK UW Equity IBM US Equity
# ADSK UW Equity 1256370D US Equity
# ADSK UW Equity 1385168D US Equity
# ADSK UW Equity AKAM US Equity
# ADSK UW Equity 1841000D US Equity
# ADSK UW Equity 1292708D US Equity
# ADSK UW Equity 1254712D US Equity
# ADSK UW Equity 1750139D US Equity
# ADSK UW Equity 1780017D LN Equity
# ADSK UW Equity 1500305D US Equity
# ADSK UW Equity 1577240D US Equity
# ADSK UW Equity HBRN ID Equity
# ADSK UW Equity 1796050D SP Equity
# ADSK UW Equity 1869803D HK Equity
# ADSK UW Equity 032190 KS Equity
# ADSK UW Equity 1526179D KS Equity
# ADSK UW Equity 1558581D US Equity
# ADSK UW Equity NSIT US Equity
# ADSK UW Equity 1803 JP Equity
# ADSK UW Equity 032190 KS Equity
# ADSK UW Equity 1563 TT Equity
# ADSK UW Equity SNX US Equity
# ADSK UW Equity 900938 CH Equity
# ADSK UW Equity 300344 CH Equity
# ADSK UW Equity 7732 JP Equity
# ADSK UW Equity 1594 TT Equity
# ADSK UW Equity 6240 TT Equity
# ADSK UW Equity 4131589Z US Equity
# ADSK UW Equity 6383 JP Equity
# ADSK UW Equity ALPRO FP Equity
# ADSK UW Equity 101930 KS Equity
# ADSK UW Equity 3352Z US Equity
# ADSK UW Equity 3570 TT Equity
# ADSK UW Equity 6123 TT Equity
# ADSK UW Equity 0390864D CN Equity
# ADSK UW Equity 0933180D US Equity
# ADSK UW Equity CNXN US Equity
# AKAM UW Equity
# AKAM UW Equity OUECT SP Equity
# AKAM UW Equity TECHM IN Equity
# AKAM UW Equity QUMU US Equity
# AKAM UW Equity BCOV US Equity
# AKAM UW Equity BXP US Equity
# AKAM UW Equity VMX FP Equity
# AKAM UW Equity AES US Equity
# AKAM UW Equity OTEX CN Equity
# AKAM UW Equity SNOW US Equity
# AKAM UW Equity INXN US Equity
# AKAM UW Equity ORCL US Equity
# AKAM UW Equity FDX US Equity
# AKAM UW Equity MAERSKB DC Equity
# AKAM UW Equity ARW US Equity
# AKAM UW Equity BABA US Equity
# AKAM UW Equity VOW GR Equity
# AKAM UW Equity AAPL US Equity
# AKAM UW Equity HD US Equity
# AKAM UW Equity META US Equity
# AKAM UW Equity T US Equity
# AKAM UW Equity STLA US Equity
# AKAM UW Equity DTE GR Equity
# AKAM UW Equity F US Equity
# AKAM UW Equity 7267 JP Equity
# AKAM UW Equity NFLX US Equity
# AKAM UW Equity AIR FP Equity
# AKAM UW Equity BBY US Equity
# AKAM UW Equity CMCSA US Equity
# AKAM UW Equity GOOGL US Equity
# AKAM UW Equity AMZN US Equity
# AKAM UW Equity MSFT US Equity
# AMAT UW Equity
# AMAT UW Equity 6323 JP Equity
# AMAT UW Equity 166090 KS Equity
# AMAT UW Equity 7012 JP Equity
# AMAT UW Equity ICHR US Equity
# AMAT UW Equity PSB US Equity
# AMAT UW Equity ROLL US Equity
# AMAT UW Equity AEIS US Equity
# AMAT UW Equity FLEX US Equity
# AMAT UW Equity MKSI US Equity
# AMAT UW Equity BHE US Equity
# AMAT UW Equity VACN SW Equity
# AMAT UW Equity AZTA US Equity
# AMAT UW Equity 7705 JP Equity
# AMAT UW Equity CLS CN Equity
# AMAT UW Equity 5333 JP Equity
# AMAT UW Equity OERL SW Equity
# AMAT UW Equity UCTT US Equity
# AMAT UW Equity ENTG US Equity
# AMAT UW Equity 064760 KS Equity
# AMAT UW Equity LASR US Equity
# AMAT UW Equity GFS US Equity
# AMAT UW Equity 000536 CH Equity
# AMAT UW Equity 2408 TT Equity
# AMAT UW Equity 294630 KS Equity
# AMAT UW Equity INTC US Equity
# AMAT UW Equity 6502 JP Equity
# AMAT UW Equity 200725 CH Equity
# AMAT UW Equity 079950 KS Equity
# AMAT UW Equity BA US Equity
# AMAT UW Equity 000660 KS Equity
# AMAT UW Equity AIR FP Equity
# AMAT UW Equity 981 HK Equity
# AMAT UW Equity 1577197D CH Equity
# AMAT UW Equity 002610 CH Equity
# AMAT UW Equity MU US Equity
# AMAT UW Equity 1726722D CH Equity
# AMAT UW Equity 005930 KS Equity
# AMAT UW Equity 6239 TT Equity
# AMAT UW Equity 2330 TT Equity
# AMAT UW Equity STM FP Equity
# AMD UW Equity
# AMD UW Equity 2449 TT Equity
# AMD UW Equity 0860008D GR Equity
# AMD UW Equity COHU US Equity
# AMD UW Equity 3706 TT Equity
# AMD UW Equity 2303 TT Equity
# AMD UW Equity 6857 JP Equity
# AMD UW Equity GFS US Equity
# AMD UW Equity 033320 KS Equity
# AMD UW Equity 005930 KS Equity
# AMD UW Equity WDC US Equity
# AMD UW Equity 3564 TT Equity
# AMD UW Equity CAP FP Equity
# AMD UW Equity 095340 KS Equity
# AMD UW Equity BESI NA Equity
# AMD UW Equity 002156 CH Equity
# AMD UW Equity 131290 KS Equity
# AMD UW Equity MU US Equity
# AMD UW Equity 2330 TT Equity
# AMD UW Equity 093520 KS Equity
# AMD UW Equity PEGA US Equity
# AMD UW Equity 992 HK Equity
# AMD UW Equity SNX US Equity
# AMD UW Equity 005930 KS Equity
# AMD UW Equity 6758 JP Equity
# AMD UW Equity ARW US Equity
# AMD UW Equity HPQ US Equity
# AMD UW Equity BBY US Equity
# AMD UW Equity MSFT US Equity
# AMD UW Equity 700 HK Equity
# AMD UW Equity AVT US Equity
# AMD UW Equity CSCO US Equity
# AMD UW Equity 2324 TT Equity
# AMD UW Equity GOOGL US Equity
# AMD UW Equity 3702 TT Equity
# AMD UW Equity AMZN US Equity
# AMD UW Equity META US Equity
# AMD UW Equity KMCACZ CH Equity
# AMD UW Equity DELL US Equity
# AMD UW Equity HPE US Equity
# AMD UW Equity 2357 TT Equity
# AMKR UW Equity
# AMKR UW Equity ONTO US Equity
# AMKR UW Equity KLIC US Equity
# AMKR UW Equity 6753 JP Equity
# AMKR UW Equity 009150 KS Equity
# AMKR UW Equity TER US Equity
# AMKR UW Equity VECO US Equity
# AMKR UW Equity 002916 CH Equity
# AMKR UW Equity KLAC US Equity
# AMKR UW Equity 3402 JP Equity
# AMKR UW Equity 077360 KS Equity
# AMKR UW Equity 6502 JP Equity
# AMKR UW Equity 353200 KS Equity
# AMKR UW Equity 042700 KS Equity
# AMKR UW Equity 039030 KS Equity
# AMKR UW Equity 4958 TT Equity
# AMKR UW Equity 272290 KS Equity
# AMKR UW Equity 6857 JP Equity
# AMKR UW Equity 131290 KS Equity
# AMKR UW Equity BESI NA Equity
# AMKR UW Equity IVAC US Equity
# AMKR UW Equity AVGO US Equity
# AMKR UW Equity AAPL US Equity
# AMKR UW Equity STM FP Equity
# AMKR UW Equity IFX GR Equity
# AMKR UW Equity 992 HK Equity
# AMKR UW Equity CRUS US Equity
# AMKR UW Equity 090460 KS Equity
# AMKR UW Equity ON US Equity
# AMKR UW Equity 005930 KS Equity
# AMKR UW Equity TXN US Equity
# AMKR UW Equity NVDA US Equity
# AMKR UW Equity 6723 JP Equity
# AMKR UW Equity MXL US Equity
# AMKR UW Equity NXPI US Equity
# AMKR UW Equity GFS US Equity
# AMKR UW Equity 6502 JP Equity
# AMKR UW Equity INTC US Equity
# AMKR UW Equity MCHP US Equity
# AMKR UW Equity 2330 TT Equity
# AMKR UW Equity QCOM US Equity
# ANET UN Equity
# ANET UN Equity 2317 TT Equity
# ANET UN Equity HPE US Equity
# ANET UN Equity INTC US Equity
# ANET UN Equity FLEX US Equity
# ANET UN Equity LITE US Equity
# ANET UN Equity NPTN US Equity
# ANET UN Equity 0047180D US Equity
# ANET UN Equity ES US Equity
# ANET UN Equity MRVL US Equity
# ANET UN Equity IBM US Equity
# ANET UN Equity TTMI US Equity
# ANET UN Equity AVGO US Equity
# ANET UN Equity 9974748Z US Equity
# ANET UN Equity NVDA US Equity
# ANET UN Equity SANM US Equity
# ANET UN Equity JBL US Equity
# ANET UN Equity MSFT US Equity
# ANET UN Equity MTSI US Equity
# ANET UN Equity HCP US Equity
# ANET UN Equity AQN CN Equity
# ANET UN Equity ORCL US Equity
# ANET UN Equity WCC US Equity
# ANET UN Equity 700 HK Equity
# ANET UN Equity GOOGL US Equity
# ANET UN Equity INFN US Equity
# ANET UN Equity SNX US Equity
# ANET UN Equity IBM US Equity
# ANET UN Equity NTAP US Equity
# ANET UN Equity MSFT US Equity
# ANET UN Equity AMZN US Equity
# ANET UN Equity PANW US Equity
# ANET UN Equity META US Equity
# ANET UN Equity SPOT US Equity
# ANET UN Equity VMW US Equity
# ANET UN Equity DELL US Equity
# ANET UN Equity PLUS US Equity
# ANET UN Equity MTDL IJ Equity
# ANET UN Equity NFLX US Equity
# ANET UN Equity HPE US Equity
# ANET UN Equity NOW US Equity
# ANSS UW Equity
# ANSS UW Equity NVDA US Equity
# ANSS UW Equity SAP GR Equity
# ANSS UW Equity PCG US Equity
# ANSS UW Equity MSFT US Equity
# ANSS UW Equity EXC US Equity
# ANSS UW Equity CDNS US Equity
# ANSS UW Equity AMD US Equity
# ANSS UW Equity PTC US Equity
# ANSS UW Equity FE US Equity
# ANSS UW Equity 0008230D US Equity
# ANSS UW Equity DSY FP Equity
# ANSS UW Equity ADSK US Equity
# ANSS UW Equity ROK US Equity
# ANSS UW Equity INTC US Equity
# ANSS UW Equity ECL US Equity
# ANSS UW Equity AQN CN Equity
# ANSS UW Equity 6947 JP Equity
# ANSS UW Equity ASKN GR Equity
# ANSS UW Equity ALU AU Equity
# ANSS UW Equity ES US Equity
# ANSS UW Equity AIR FP Equity
# ANSS UW Equity KMCACZ CH Equity
# ANSS UW Equity 1003Z GR Equity
# ANSS UW Equity 005930 KS Equity
# ANSS UW Equity CAT US Equity
# ANSS UW Equity 992 HK Equity
# ANSS UW Equity 1237108D US Equity
# ANSS UW Equity UPS US Equity
# ANSS UW Equity BA US Equity
# ANSS UW Equity 0893204D US Equity
# ANSS UW Equity GE US Equity
# ANSS UW Equity 0867322D US Equity
# ANSS UW Equity RR/ LN Equity
# ANSS UW Equity LMT US Equity
# ANSS UW Equity NESN SW Equity
# ANSS UW Equity 1310070D US Equity
# ANSS UW Equity 0238301Z US Equity
# ANSS UW Equity 000063 CH Equity
# ANSS UW Equity 0154367D CP Equity
# ANSS UW Equity 0219834Z US Equity
# APH UN Equity
# APH UN Equity CTS US Equity
# APH UN Equity 6442 TT Equity
# APH UN Equity 600255 CH Equity
# APH UN Equity 3492 TT Equity
# APH UN Equity ZBRA US Equity
# APH UN Equity AQN CN Equity
# APH UN Equity 9503 JP Equity
# APH UN Equity 2233 TT Equity
# APH UN Equity 603703 CH Equity
# APH UN Equity 603203 CH Equity
# APH UN Equity 000062 CH Equity
# APH UN Equity AES US Equity
# APH UN Equity 300328 CH Equity
# APH UN Equity 002815 CH Equity
# APH UN Equity 002897 CH Equity
# APH UN Equity MPWR US Equity
# APH UN Equity ELG GR Equity
# APH UN Equity 6672 TT Equity
# APH UN Equity SOG FP Equity
# APH UN Equity 032940 KS Equity
# APH UN Equity 000063 CH Equity
# APH UN Equity HON US Equity
# APH UN Equity ARW US Equity
# APH UN Equity F US Equity
# APH UN Equity VOW GR Equity
# APH UN Equity BRK/A US Equity
# APH UN Equity 066570 KS Equity
# APH UN Equity AVT US Equity
# APH UN Equity STLA US Equity
# APH UN Equity NOC US Equity
# APH UN Equity CSCO US Equity
# APH UN Equity DELL US Equity
# APH UN Equity WCC US Equity
# APH UN Equity SNX US Equity
# APH UN Equity RTX US Equity
# APH UN Equity 005930 KS Equity
# APH UN Equity AAPL US Equity
# APH UN Equity GM US Equity
# APH UN Equity BA/ LN Equity
# APH UN Equity HPE US Equity
# ASML UW Equity
# ASML UW Equity 6954 JP Equity
# ASML UW Equity MKSI US Equity
# ASML UW Equity VACN SW Equity
# ASML UW Equity UCTT US Equity
# ASML UW Equity INTO BB Equity
# ASML UW Equity ATE FP Equity
# ASML UW Equity BHE US Equity
# ASML UW Equity LITE US Equity
# ASML UW Equity 7731 JP Equity
# ASML UW Equity RWE GR Equity
# ASML UW Equity AZTA US Equity
# ASML UW Equity IBE SM Equity
# ASML UW Equity ES US Equity
# ASML UW Equity 3023 TT Equity
# ASML UW Equity AALB NA Equity
# ASML UW Equity 1701392Z GR Equity
# ASML UW Equity PCG US Equity
# ASML UW Equity IIVI US Equity
# ASML UW Equity CAP FP Equity
# ASML UW Equity ENTG US Equity
# ASML UW Equity 6600 JP Equity
# ASML UW Equity 1726722D CH Equity
# ASML UW Equity 300655 CH Equity
# ASML UW Equity 2303 TT Equity
# ASML UW Equity AAPL US Equity
# ASML UW Equity 000660 KS Equity
# ASML UW Equity 2330 TT Equity
# ASML UW Equity 005930 KS Equity
# ASML UW Equity GFS US Equity
# ASML UW Equity 981 HK Equity
# ASML UW Equity 1577197D CH Equity
# ASML UW Equity MU US Equity
# ASML UW Equity 2408 TT Equity
# ASML UW Equity INTC US Equity
# ASML UW Equity SHUHGZ CH Equity
# AVGO UW Equity
# AVGO UW Equity FLEX US Equity
# AVGO UW Equity 2303 TT Equity
# AVGO UW Equity KEYS US Equity
# AVGO UW Equity GFS US Equity
# AVGO UW Equity 011070 KS Equity
# AVGO UW Equity WDC US Equity
# AVGO UW Equity 033170 KS Equity
# AVGO UW Equity 600584 CH Equity
# AVGO UW Equity 095340 KS Equity
# AVGO UW Equity DSY FP Equity
# AVGO UW Equity AMKR US Equity
# AVGO UW Equity 002156 CH Equity
# AVGO UW Equity MTRN US Equity
# AVGO UW Equity 2449 TT Equity
# AVGO UW Equity KLAC US Equity
# AVGO UW Equity TSEM IT Equity
# AVGO UW Equity 2330 TT Equity
# AVGO UW Equity 3105 TT Equity
# AVGO UW Equity 3711 TT Equity
# AVGO UW Equity 3436 JP Equity
# AVGO UW Equity KMCACZ CH Equity
# AVGO UW Equity WCC US Equity
# AVGO UW Equity DELL US Equity
# AVGO UW Equity 7537 JP Equity
# AVGO UW Equity CDW US Equity
# AVGO UW Equity SCSC US Equity
# AVGO UW Equity 005930 KS Equity
# AVGO UW Equity HPE US Equity
# AVGO UW Equity AVT US Equity
# AVGO UW Equity ERICB SS Equity
# AVGO UW Equity AMZN US Equity
# AVGO UW Equity ARW US Equity
# AVGO UW Equity 2317 TT Equity
# AVGO UW Equity 011070 KS Equity
# AVGO UW Equity 3702 TT Equity
# AVGO UW Equity 3033 TT Equity
# AVGO UW Equity 3132 JP Equity
# AVGO UW Equity AAPL US Equity
# AVGO UW Equity SNX US Equity
# AVGO UW Equity 3036 TT Equity
# AZTA UW Equity
# AZTA UW Equity NG/ LN Equity
# AZTA UW Equity AES US Equity
# AZTA UW Equity PLXS US Equity
# AZTA UW Equity ED US Equity
# AZTA UW Equity PCG US Equity
# AZTA UW Equity UTL US Equity
# AZTA UW Equity 3680 TT Equity
# AZTA UW Equity SRE US Equity
# AZTA UW Equity DUK US Equity
# AZTA UW Equity 300580 CH Equity
# AZTA UW Equity CYBE US Equity
# AZTA UW Equity 114810 KS Equity
# AZTA UW Equity VACN SW Equity
# AZTA UW Equity VECO US Equity
# AZTA UW Equity MU US Equity
# AZTA UW Equity 042380 KF Equity
# AZTA UW Equity KLAC US Equity
# AZTA UW Equity LRCX US Equity
# AZTA UW Equity ASML NA Equity
# AZTA UW Equity 084370 KS Equity
# AZTA UW Equity 8035 JP Equity
# AZTA UW Equity 2330 TT Equity
# AZTA UW Equity ONTO US Equity
# AZTA UW Equity ASM NA Equity
# AZTA UW Equity 005930 KS Equity
# AZTA UW Equity IFX GR Equity
# AZTA UW Equity TMO US Equity
# AZTA UW Equity AMAT US Equity
# AZTA UW Equity BESI NA Equity
# AZTA UW Equity 981 HK Equity
# AZTA UW Equity 000660 KS Equity
# AZTA UW Equity 002371 CH Equity
# AZTA UW Equity 2303 TT Equity
# BR UN Equity
# BR UN Equity GNL US Equity
# BR UN Equity UPS US Equity
# BR UN Equity QMCI US Equity
# BR UN Equity 3352Z US Equity
# BR UN Equity IBM US Equity
# BR UN Equity 6507Z US Equity
# BR UN Equity ASUR US Equity
# BR UN Equity BTV CN Equity
# BR UN Equity FTRCQ US Equity
# BR UN Equity UBSG SW Equity
# CDAY UN Equity
# CDNS UW Equity
# CDNS UW Equity PCG US Equity
# CDNS UW Equity SOI FP Equity
# CDNS UW Equity NET US Equity
# CDNS UW Equity RMBS US Equity
# CDNS UW Equity FLT SP Equity
# CDNS UW Equity XPER US Equity
# CDNS UW Equity MRAM US Equity
# CDNS UW Equity AMD US Equity
# CDNS UW Equity OKTA US Equity
# CDNS UW Equity 0127372D US Equity
# CDNS UW Equity 1012753D IT Equity
# CDNS UW Equity 0852008D LN Equity
# CDNS UW Equity 2454 TT Equity
# CDNS UW Equity 005930 KS Equity
# CDNS UW Equity 0857572D US Equity
# CDNS UW Equity 0289399D US Equity
# CDNS UW Equity 108320 KS Equity
# CDNS UW Equity 0053963D US Equity
# CDNS UW Equity KMCACZ CH Equity
# CDNS UW Equity 0348259Z US Equity
# CDNS UW Equity 066570 KS Equity
# CDNS UW Equity JNPR US Equity
# CDNS UW Equity 0408408D US Equity
# CDNS UW Equity 0685406D US Equity
# CDNS UW Equity 012330 KS Equity
# CDNS UW Equity 1064816D US Equity
# CDNS UW Equity 002405 CH Equity
# CDNS UW Equity 0701262D CH Equity
# CDNS UW Equity 0009050D US Equity
# CDW UW Equity
# CDW UW Equity 4902 JP Equity
# CDW UW Equity 992 HK Equity
# CDW UW Equity INTC US Equity
# CDW UW Equity FDX US Equity
# CDW UW Equity 7751 JP Equity
# CDW UW Equity AAPL US Equity
# CDW UW Equity UPS US Equity
# CDW UW Equity NVDA US Equity
# CDW UW Equity ADBE US Equity
# CDW UW Equity LOGN SW Equity
# CDW UW Equity CSCO US Equity
# CDW UW Equity 6758 JP Equity
# CDW UW Equity 005930 KS Equity
# CDW UW Equity GOOGL US Equity
# CDW UW Equity AVGO US Equity
# CDW UW Equity IBM US Equity
# CDW UW Equity HPE US Equity
# CDW UW Equity HPQ US Equity
# CDW UW Equity MSFT US Equity
# CDW UW Equity DELL US Equity
# CDW UW Equity LRN US Equity
# CDW UW Equity SNX US Equity
# CDW UW Equity ALESK FP Equity
# CDW UW Equity 0228856Z US Equity
# CDW UW Equity ENJYQ US Equity
# CDW UW Equity 0834219D US Equity
# CDW UW Equity BGGSQ US Equity
# CDW UW Equity 3352Z US Equity
# CRM UN Equity
# CRM UN Equity SWCH US Equity
# CRM UN Equity HPP US Equity
# CRM UN Equity CAI AV Equity
# CRM UN Equity NOKIA FH Equity
# CRM UN Equity PDM US Equity
# CRM UN Equity MTSI US Equity
# CRM UN Equity PTC US Equity
# CRM UN Equity MHH US Equity
# CRM UN Equity CAP FP Equity
# CRM UN Equity ADBE US Equity
# CRM UN Equity BXP US Equity
# CRM UN Equity EQC US Equity
# CRM UN Equity GFC FP Equity
# CRM UN Equity ADN1 GR Equity
# CRM UN Equity PBI US Equity
# CRM UN Equity ZUO US Equity
# CRM UN Equity MPHL IN Equity
# CRM UN Equity KRC US Equity
# CRM UN Equity JNPR US Equity
# CRM UN Equity 9984 JP Equity
# CRM UN Equity REV US Equity
# CRM UN Equity 1938073D US Equity
# CRM UN Equity BEZQ IT Equity
# CRM UN Equity BCOM IT Equity
# CRM UN Equity LODHA IN Equity
# CRM UN Equity 2998954Z US Equity
# CRM UN Equity 9880 JP Equity
# CRM UN Equity LT IN Equity
# CRM UN Equity 5091Z US Equity
# CRM UN Equity ZUO US Equity
# CRM UN Equity AOF GR Equity
# CRM UN Equity RBOS GR Equity
# CRM UN Equity SNX US Equity
# CRM UN Equity PSYS IN Equity
# CRM UN Equity VERX US Equity
# CRM UN Equity SREV US Equity
# CRM UN Equity KDA CN Equity
# CRM UN Equity RW IN Equity
# CRM UN Equity 3240627Z US Equity
# CRM UN Equity 4324 JP Equity
# CSCO UW Equity
# CSCO UW Equity FLEX US Equity
# CSCO UW Equity NVDA US Equity
# CSCO UW Equity AVGO US Equity
# CSCO UW Equity 2454 TT Equity
# CSCO UW Equity WDC US Equity
# CSCO UW Equity STX US Equity
# CSCO UW Equity AMD US Equity
# CSCO UW Equity LITE US Equity
# CSCO UW Equity VIAV US Equity
# CSCO UW Equity MU US Equity
# CSCO UW Equity INTC US Equity
# CSCO UW Equity NPTN US Equity
# CSCO UW Equity STM FP Equity
# CSCO UW Equity IIVI US Equity
# CSCO UW Equity JBL US Equity
# CSCO UW Equity QRVO US Equity
# CSCO UW Equity KEYS US Equity
# CSCO UW Equity APH US Equity
# CSCO UW Equity FN US Equity
# CSCO UW Equity 2317 TT Equity
# CSCO UW Equity VZ US Equity
# CSCO UW Equity TMUS US Equity
# CSCO UW Equity CDW US Equity
# CSCO UW Equity GD US Equity
# CSCO UW Equity DCC LN Equity
# CSCO UW Equity REDI IN Equity
# CSCO UW Equity CCC LN Equity
# CSCO UW Equity ALSN SW Equity
# CSCO UW Equity NSIT US Equity
# CSCO UW Equity MSFT US Equity
# CSCO UW Equity T US Equity
# CSCO UW Equity ORA FP Equity
# CSCO UW Equity 900938 CH Equity
# CSCO UW Equity SCSC US Equity
# CSCO UW Equity HCLT IN Equity
# CSCO UW Equity PLUS US Equity
# CSCO UW Equity IBM US Equity
# CSCO UW Equity BC8 GR Equity
# CSCO UW Equity SNX US Equity
# CSCO UW Equity 9432 JP Equity
# CTSH UW Equity
# CTSH UW Equity CSCO US Equity
# CTSH UW Equity CRM US Equity
# CTSH UW Equity NTAP US Equity
# CTSH UW Equity TEMN SW Equity
# CTSH UW Equity BIRET IN Equity
# CTSH UW Equity AIT SP Equity
# CTSH UW Equity CREI LN Equity
# CTSH UW Equity 0133909D CN Equity
# CTSH UW Equity EQN LN Equity
# CTSH UW Equity ADBE US Equity
# CTSH UW Equity 0731989D US Equity
# CTSH UW Equity BLSTR IN Equity
# CTSH UW Equity ZBRA US Equity
# CTSH UW Equity ORCL US Equity
# CTSH UW Equity 0408962Z US Equity
# CTSH UW Equity PEGA US Equity
# CTSH UW Equity ACIW US Equity
# CTSH UW Equity EMBASSY IN Equity
# CTSH UW Equity DLN LN Equity
# CTSH UW Equity PTC US Equity
# CTSH UW Equity 1691694D US Equity
# CTSH UW Equity KXS CN Equity
# CTSH UW Equity 1037Z IN Equity
# CTSH UW Equity III US Equity
# CTSH UW Equity DCT US Equity
# CTSH UW Equity CNA LN Equity
# CTSH UW Equity BL US Equity
# CTSH UW Equity GTK NZ Equity
# CTSH UW Equity INCH LN Equity
# CTSH UW Equity ACIW US Equity
# CTSH UW Equity VOLCARB SS Equity
# CTSH UW Equity JDAS US Equity
# CTSH UW Equity ZURN SW Equity
# CTSH UW Equity RHT CN Equity
# CTSH UW Equity ORI AU Equity
# CTSH UW Equity MSFT US Equity
# CTSH UW Equity 92836Z US Equity
# CTSH UW Equity PAYX US Equity
# CTSH UW Equity CLGX US Equity
# CTSH UW Equity 0220072D US Equity
# CTXS UW Equity
# CTXS UW Equity 1611364D US Equity
# CTXS UW Equity 033230 KS Equity
# CTXS UW Equity AMZN US Equity
# CTXS UW Equity WDC US Equity
# CTXS UW Equity DUST SS Equity
# CTXS UW Equity NTCT US Equity
# CTXS UW Equity NTAP US Equity
# CTXS UW Equity CVLT US Equity
# CTXS UW Equity GOOGL US Equity
# CTXS UW Equity NOW US Equity
# CTXS UW Equity CRM US Equity
# CTXS UW Equity 1972 HK Equity
# CTXS UW Equity IGP LN Equity
# CTXS UW Equity HPE US Equity
# CTXS UW Equity ADBE US Equity
# CTXS UW Equity FLEX US Equity
# CTXS UW Equity NVDA US Equity
# CTXS UW Equity CGM FP Equity
# CTXS UW Equity MSFT US Equity
# CTXS UW Equity SWCH US Equity
# CTXS UW Equity ARW US Equity
# CTXS UW Equity 023590 KS Equity
# CTXS UW Equity NSIT US Equity
# CTXS UW Equity 992 HK Equity
# CTXS UW Equity CNXN US Equity
# CTXS UW Equity 2352 TT Equity
# CTXS UW Equity 0878306D SP Equity
# CTXS UW Equity 941 HK Equity
# CTXS UW Equity 030200 KS Equity
# CTXS UW Equity 6163 TT Equity
# CTXS UW Equity CCC LN Equity
# CTXS UW Equity GE US Equity
# CTXS UW Equity 6112 TT Equity
# CTXS UW Equity SNX US Equity
# CTXS UW Equity 0208097D CN Equity
# CTXS UW Equity 2480 TT Equity
# CTXS UW Equity 032190 KS Equity
# CTXS UW Equity PLUS US Equity
# CTXS UW Equity 3565 JP Equity
# CTXS UW Equity KMCACZ CH Equity
# DXC UN Equity
# DXC UN Equity QLYS US Equity
# DXC UN Equity 9758 JP Equity
# DXC UN Equity PEGA US Equity
# DXC UN Equity ZBRA US Equity
# DXC UN Equity INXN US Equity
# DXC UN Equity OTEX CN Equity
# DXC UN Equity NOW US Equity
# DXC UN Equity MPHL IN Equity
# DXC UN Equity SAP GR Equity
# DXC UN Equity CAI AV Equity
# DXC UN Equity CTXS US Equity
# DXC UN Equity IMCI US Equity
# DXC UN Equity XSL IN Equity
# DXC UN Equity HPT VN Equity
# DXC UN Equity VMW US Equity
# DXC UN Equity NTAP US Equity
# DXC UN Equity ATEB BB Equity
# DXC UN Equity SPSC US Equity
# DXC UN Equity GZAV RU Equity
# DXC UN Equity TEMN SW Equity
# DXC UN Equity NOW US Equity
# DXC UN Equity 0078838Z IT Equity
# DXC UN Equity 1319293D JP Equity
# DXC UN Equity 3601Z GR Equity
# DXC UN Equity 2833000Z LN Equity
# DXC UN Equity FREDQ US Equity
# DXC UN Equity AEROMEX* MM Equity
# DXC UN Equity ZURN SW Equity
# DXC UN Equity QHCCQ US Equity
# DXC UN Equity CSMG3 BZ Equity
# DXC UN Equity SABR US Equity
# DXC UN Equity 0251066D JP Equity
# DXC UN Equity III US Equity
# DXC UN Equity 601717 CH Equity
# DXC UN Equity PAN VN Equity
# DXC UN Equity XSL IN Equity
# DXC UN Equity 3383Z LN Equity
# DXC UN Equity MANU US Equity
# DXC UN Equity 8206440Z LN Equity
# DXC UN Equity 8267 JP Equity
# ENPH UQ Equity
# ENPH UQ Equity PTC US Equity
# ENPH UQ Equity FLEX US Equity
# ENPH UQ Equity PCG US Equity
# ENPH UQ Equity IFX GR Equity
# ENPH UQ Equity AOSL US Equity
# ENPH UQ Equity SLAB US Equity
# ENPH UQ Equity 300207 CH Equity
# ENPH UQ Equity 300750 CH Equity
# ENPH UQ Equity 1604475D IN Equity
# ENPH UQ Equity 0867322D US Equity
# ENPH UQ Equity 6762 JP Equity
# ENPH UQ Equity 3023 TT Equity
# ENPH UQ Equity ADT US Equity
# ENPH UQ Equity 009830 KS Equity
# ENPH UQ Equity BYW6 GR Equity
# ENPH UQ Equity 6541516Z GR Equity
# ENPH UQ Equity NOVA US Equity
# ENPH UQ Equity 220638Z FP Equity
# ENPH UQ Equity 1033638Z US Equity
# ENPH UQ Equity 066570 KS Equity
# ENPH UQ Equity 1271906D US Equity
# ENPH UQ Equity MAXN US Equity
# ENPH UQ Equity RUN US Equity
# ENPH UQ Equity 002056 CH Equity
# ENPH UQ Equity 601012 CH Equity
# ENPH UQ Equity 1525Z AU Equity
# ENPH UQ Equity 0366584D AU Equity
# ENPH UQ Equity 6752 JP Equity
# ENPH UQ Equity JKS US Equity
# ENPH UQ Equity 6028222Z AU Equity
# ENPH UQ Equity 982541Q US Equity
# ENPH UQ Equity 7723904Z AU Equity
# ENTG UW Equity
# ENTG UW Equity XEL US Equity
# ENTG UW Equity 9506 JP Equity
# ENTG UW Equity 056730 KS Equity
# ENTG UW Equity UTL US Equity
# ENTG UW Equity 9508 JP Equity
# ENTG UW Equity 9501 JP Equity
# ENTG UW Equity ETR US Equity
# ENTG UW Equity 300260 CH Equity
# ENTG UW Equity SRE US Equity
# ENTG UW Equity 9503 JP Equity
# ENTG UW Equity ES US Equity
# ENTG UW Equity IBE SM Equity
# ENTG UW Equity NG/ LN Equity
# ENTG UW Equity 053690 KS Equity
# ENTG UW Equity INTC US Equity
# ENTG UW Equity AMAT US Equity
# ENTG UW Equity 3374 JP Equity
# ENTG UW Equity LRCX US Equity
# ENTG UW Equity 2330 TT Equity
# ENTG UW Equity 981 HK Equity
# ENTG UW Equity CTVA US Equity
# ENTG UW Equity 8091 TT Equity
# ENTG UW Equity 8035 JP Equity
# ENTG UW Equity ASML NA Equity
# ENTG UW Equity ASM NA Equity
# ENTG UW Equity TXN US Equity
# ENTG UW Equity 7731 JP Equity
# ENTG UW Equity 005930 KS Equity
# ENTG UW Equity 7472 JP Equity
# ENTG UW Equity 2303 TT Equity
# ENTG UW Equity 3680 TT Equity
# ENTG UW Equity 7751 JP Equity
# EPAM UN Equity
# EPAM UN Equity 1936097D VI Equity
# EPAM UN Equity PTC US Equity
# EPAM UN Equity CRM US Equity
# EPAM UN Equity ADBE US Equity
# EPAM UN Equity GWI LN Equity
# EPAM UN Equity 2523946Z LN Equity
# EPAM UN Equity MBG GR Equity
# EPAM UN Equity ADBE US Equity
# FFIV UW Equity
# FFIV UW Equity FLEX US Equity
# FFIV UW Equity 6561 TT Equity
# FFIV UW Equity NG/ LN Equity
# FFIV UW Equity AVA US Equity
# FFIV UW Equity ZUO US Equity
# FFIV UW Equity ENEA SS Equity
# FFIV UW Equity PCG US Equity
# FFIV UW Equity OPI US Equity
# FFIV UW Equity XEL US Equity
# FFIV UW Equity NVDA US Equity
# FFIV UW Equity OTEX CN Equity
# FFIV UW Equity 596 HK Equity
# FFIV UW Equity ANET US Equity
# FFIV UW Equity ZM US Equity
# FFIV UW Equity UTL US Equity
# FFIV UW Equity IBM US Equity
# FFIV UW Equity EQIX US Equity
# FFIV UW Equity DELL US Equity
# FFIV UW Equity ORCL US Equity
# FFIV UW Equity AMZN US Equity
# FFIV UW Equity CSCO US Equity
# FFIV UW Equity CNXN US Equity
# FFIV UW Equity NSIT US Equity
# FFIV UW Equity CCC LN Equity
# FFIV UW Equity SCSC US Equity
# FFIV UW Equity BABA US Equity
# FFIV UW Equity SNX US Equity
# FFIV UW Equity GOOGL US Equity
# FFIV UW Equity DTC SJ Equity
# FFIV UW Equity NRO FP Equity
# FFIV UW Equity 728 HK Equity
# FFIV UW Equity HPE US Equity
# FFIV UW Equity ARW US Equity
# FFIV UW Equity MSFT US Equity
# FFIV UW Equity MELI US Equity
# FIS UN Equity
# FIS UN Equity DFS US Equity
# FIS UN Equity PRGS US Equity
# FIS UN Equity ELRN IT Equity
# FIS UN Equity VRE US Equity
# FIS UN Equity PUB FP Equity
# FIS UN Equity ADBE US Equity
# FIS UN Equity CRM US Equity
# FIS UN Equity GILT IT Equity
# FIS UN Equity VNET LN Equity
# FIS UN Equity AX-U CN Equity
# FIS UN Equity MITK US Equity
# FIS UN Equity QMCI US Equity
# FIS UN Equity V US Equity
# FIS UN Equity NUAN US Equity
# FIS UN Equity MA US Equity
# FIS UN Equity AXP US Equity
# FIS UN Equity BOKU LN Equity
# FIS UN Equity PCIP LN Equity
# FIS UN Equity LMRK US Equity
# FIS UN Equity FLT US Equity
# FIS UN Equity OGD CN Equity
# FIS UN Equity SNX US Equity
# FIS UN Equity BMO CN Equity
# FIS UN Equity LITB US Equity
# FIS UN Equity AIR FP Equity
# FIS UN Equity GKS GR Equity
# FIS UN Equity HRB US Equity
# FIS UN Equity THG LN Equity
# FIS UN Equity EFX US Equity
# FIS UN Equity ACIW US Equity
# FISV UW Equity
# FISV UW Equity GBG LN Equity
# FISV UW Equity ATGN US Equity
# FISV UW Equity MCRO LN Equity
# FISV UW Equity ING FP Equity
# FISV UW Equity MITK US Equity
# FISV UW Equity APPS US Equity
# FISV UW Equity AFRM US Equity
# FISV UW Equity ADBE US Equity
# FISV UW Equity BOKU LN Equity
# FISV UW Equity 5490 TT Equity
# FISV UW Equity CLPS US Equity
# FISV UW Equity MA US Equity
# FISV UW Equity EMBASSY IN Equity
# FISV UW Equity VRE US Equity
# FISV UW Equity 3664 TT Equity
# FISV UW Equity DLX US Equity
# FISV UW Equity KEYS US Equity
# FISV UW Equity PDM US Equity
# FISV UW Equity ACIW US Equity
# FISV UW Equity 004800 KS Equity
# FISV UW Equity TBK US Equity
# FISV UW Equity CABK SM Equity
# FISV UW Equity NAB AU Equity
# FISV UW Equity CTLP US Equity
# FISV UW Equity DBK GR Equity
# FISV UW Equity KRNY US Equity
# FISV UW Equity 005930 KS Equity
# FISV UW Equity AAPL US Equity
# FISV UW Equity 1314951D US Equity
# FISV UW Equity CNHU US Equity
# FISV UW Equity HSBK KZ Equity
# FISV UW Equity MULN US Equity
# FISV UW Equity GOOGL US Equity
# FLT UN Equity
# FLT UN Equity MA US Equity
# FLT UN Equity ECOR3 BZ Equity
# FLT UN Equity CAMP US Equity
# FLT UN Equity SPLK US Equity
# FLT UN Equity ML FP Equity
# FLT UN Equity ITUB4 BZ Equity
# FLT UN Equity 9941Z US Equity
# FLT UN Equity SHEL LN Equity
# FLT UN Equity FIS US Equity
# FLT UN Equity TA US Equity
# FLT UN Equity 1794738D US Equity
# FLT UN Equity BP/ LN Equity
# FLT UN Equity MPC US Equity
# FLT UN Equity TRK US Equity
# FLT UN Equity 479044Z US Equity
# FLT UN Equity VBBR3 BZ Equity
# FLT UN Equity OMC US Equity
# FLT UN Equity VOW GR Equity
# FLT UN Equity CASY US Equity
# FLT UN Equity CASEYZ HK Equity
# FLT UN Equity 8250203Z US Equity
# FLT UN Equity VEA AU Equity
# FLT UN Equity CRNC US Equity
# FTNT UW Equity
# FTNT UW Equity 6166 TT Equity
# FTNT UW Equity KEYS US Equity
# FTNT UW Equity 6875 JP Equity
# FTNT UW Equity 2303 TT Equity
# FTNT UW Equity WDC US Equity
# FTNT UW Equity 900938 CH Equity
# FTNT UW Equity 3035 TT Equity
# FTNT UW Equity 6723 JP Equity
# FTNT UW Equity 3260 TT Equity
# FTNT UW Equity 2330 TT Equity
# FTNT UW Equity NVDA US Equity
# FTNT UW Equity 3558 TT Equity
# FTNT UW Equity 6502 JP Equity
# FTNT UW Equity 2377 TT Equity
# FTNT UW Equity AMD US Equity
# FTNT UW Equity FLEX US Equity
# FTNT UW Equity 8050 TT Equity
# FTNT UW Equity ANET US Equity
# FTNT UW Equity 005930 KS Equity
# FTNT UW Equity 3231 TT Equity
# FTNT UW Equity 6486 TT Equity
# FTNT UW Equity 4068773Z FP Equity
# FTNT UW Equity 046110 KS Equity
# FTNT UW Equity 2480 TT Equity
# FTNT UW Equity 6163 TT Equity
# FTNT UW Equity PLUS US Equity
# FTNT UW Equity ARW US Equity
# FTNT UW Equity 3147 TT Equity
# FTNT UW Equity 1523397D US Equity
# FTNT UW Equity SNX US Equity
# FTNT UW Equity 3352Z US Equity
# FTNT UW Equity CNXN US Equity
# FTNT UW Equity CCC LN Equity
# FTNT UW Equity NSIT US Equity
# FTNT UW Equity 2453 TT Equity
# FTNT UW Equity SCSC US Equity
# FTNT UW Equity 222810 KS Equity
# FTNT UW Equity 2468 TT Equity
# FTNT UW Equity 2427 TT Equity
# FTNT UW Equity 4131589Z US Equity
# GLW UN Equity
# GLW UN Equity LFUS US Equity
# GLW UN Equity ZBRA US Equity
# GLW UN Equity 002426 CH Equity
# GLW UN Equity 056190 KS Equity
# GLW UN Equity 1726 TT Equity
# GLW UN Equity 069330 KS Equity
# GLW UN Equity 089790 KS Equity
# GLW UN Equity 2013 TT Equity
# GLW UN Equity 050320 KS Equity
# GLW UN Equity 002303 CH Equity
# GLW UN Equity ADV GR Equity
# GLW UN Equity 002547 CH Equity
# GLW UN Equity INTT US Equity
# GLW UN Equity 002765 CH Equity
# GLW UN Equity 300256 CH Equity
# GLW UN Equity 069540 KS Equity
# GLW UN Equity 065770 KS Equity
# GLW UN Equity 215790 KS Equity
# GLW UN Equity 071280 KS Equity
# GLW UN Equity IIVI US Equity
# GLW UN Equity VOW GR Equity
# GLW UN Equity VZ US Equity
# GLW UN Equity 2409 TT Equity
# GLW UN Equity 3481 TT Equity
# GLW UN Equity 005930 KS Equity
# GLW UN Equity DELL US Equity
# GLW UN Equity AAPL US Equity
# GLW UN Equity MBG GR Equity
# GLW UN Equity WCC US Equity
# GLW UN Equity INTC US Equity
# GLW UN Equity T US Equity
# GLW UN Equity PFE US Equity
# GLW UN Equity HPQ US Equity
# GLW UN Equity 200725 CH Equity
# GLW UN Equity KMCACZ CH Equity
# GLW UN Equity 992 HK Equity
# GLW UN Equity 3673 TT Equity
# GLW UN Equity LUMN US Equity
# GLW UN Equity MSFT US Equity
# GLW UN Equity 034220 KS Equity
# GPN UN Equity
# GPN UN Equity HBRN ID Equity
# GPN UN Equity ACSO LN Equity
# GPN UN Equity 600100 CH Equity
# GPN UN Equity ACIW US Equity
# GPN UN Equity 300479 CH Equity
# GPN UN Equity MA US Equity
# GPN UN Equity SPLK US Equity
# GPN UN Equity SWCH US Equity
# GPN UN Equity USIO US Equity
# GPN UN Equity HIW US Equity
# GPN UN Equity CTLP US Equity
# GPN UN Equity BARC LN Equity
# GPN UN Equity HSBA LN Equity
# GPN UN Equity AXP US Equity
# GPN UN Equity USIO US Equity
# GPN UN Equity PYPL US Equity
# GPN UN Equity CNXN US Equity
# GPN UN Equity NVEI CN Equity
# GPN UN Equity 678 HK Equity
# GPN UN Equity MA US Equity
# GPN UN Equity 0646516D SM Equity
# GPN UN Equity V US Equity
# GPN UN Equity 7656063Z US Equity
# GPN UN Equity QSP-U CN Equity
# GPN UN Equity 1763872D CN Equity
# GPN UN Equity STRA US Equity
# GPN UN Equity MULN US Equity
# GPN UN Equity 1655490D CH Equity
# GPN UN Equity ACIW US Equity
# GPN UN Equity DFS US Equity
# HPE UN Equity
# HPE UN Equity NVDA US Equity
# HPE UN Equity APH US Equity
# HPE UN Equity BHE US Equity
# HPE UN Equity MU US Equity
# HPE UN Equity INTC US Equity
# HPE UN Equity ANET US Equity
# HPE UN Equity AVGO US Equity
# HPE UN Equity FLEX US Equity
# HPE UN Equity SANM US Equity
# HPE UN Equity JBL US Equity
# HPE UN Equity 000660 KS Equity
# HPE UN Equity WDC US Equity
# HPE UN Equity CLS CN Equity
# HPE UN Equity 2317 TT Equity
# HPE UN Equity 2356 TT Equity
# HPE UN Equity STX US Equity
# HPE UN Equity AMD US Equity
# HPE UN Equity 992 HK Equity
# HPE UN Equity 3231 TT Equity
# HPE UN Equity 2324 TT Equity
# HPE UN Equity ALSN SW Equity
# HPE UN Equity BT/A LN Equity
# HPE UN Equity DTC SJ Equity
# HPE UN Equity DOX US Equity
# HPE UN Equity GIB/A CN Equity
# HPE UN Equity SAP GR Equity
# HPE UN Equity ARW US Equity
# HPE UN Equity MSFT US Equity
# HPE UN Equity SNX US Equity
# HPE UN Equity TECHM IN Equity
# HPE UN Equity SCSC US Equity
# HPE UN Equity ACN US Equity
# HPE UN Equity VMW US Equity
# HPE UN Equity CDW US Equity
# HPE UN Equity BC8 GR Equity
# HPE UN Equity CCC LN Equity
# HPE UN Equity ATEA NO Equity
# HPE UN Equity 900938 CH Equity
# HPE UN Equity ADBE US Equity
# HPE UN Equity CAP FP Equity
# HPQ UN Equity
# HPQ UN Equity WDC US Equity
# HPQ UN Equity 3231 TT Equity
# HPQ UN Equity MSFT US Equity
# HPQ UN Equity 000660 KS Equity
# HPQ UN Equity NVDA US Equity
# HPQ UN Equity 200725 CH Equity
# HPQ UN Equity STX US Equity
# HPQ UN Equity MU US Equity
# HPQ UN Equity 2356 TT Equity
# HPQ UN Equity 2324 TT Equity
# HPQ UN Equity 002475 CH Equity
# HPQ UN Equity STM FP Equity
# HPQ UN Equity 4938 TT Equity
# HPQ UN Equity 2317 TT Equity
# HPQ UN Equity CLS CN Equity
# HPQ UN Equity INTC US Equity
# HPQ UN Equity AMD US Equity
# HPQ UN Equity 7751 JP Equity
# HPQ UN Equity JBL US Equity
# HPQ UN Equity 2382 TT Equity
# HPQ UN Equity CDW US Equity
# HPQ UN Equity CNXN US Equity
# HPQ UN Equity CA FP Equity
# HPQ UN Equity 8282 JP Equity
# HPQ UN Equity 941 HK Equity
# HPQ UN Equity BBY US Equity
# HPQ UN Equity 2730 JP Equity
# HPQ UN Equity 002024 CH Equity
# HPQ UN Equity CEC GR Equity
# HPQ UN Equity LIVEPOL1 MM Equity
# HPQ UN Equity CONN US Equity
# HPQ UN Equity CO FP Equity
# HPQ UN Equity MTDL IJ Equity
# HPQ UN Equity CCC LN Equity
# HPQ UN Equity NESN SW Equity
# HPQ UN Equity 002232 CH Equity
# HPQ UN Equity NSIT US Equity
# HPQ UN Equity 0008626D US Equity
# HPQ UN Equity PLUS US Equity
# HPQ UN Equity SNX US Equity
# IBM UN Equity
# IBM UN Equity INTC US Equity
# IBM UN Equity MU US Equity
# IBM UN Equity FFIV US Equity
# IBM UN Equity ORCL US Equity
# IBM UN Equity FLEX US Equity
# IBM UN Equity 4674 JP Equity
# IBM UN Equity CLS CN Equity
# IBM UN Equity 3817 JP Equity
# IBM UN Equity 4662 JP Equity
# IBM UN Equity CAP FP Equity
# IBM UN Equity CTG US Equity
# IBM UN Equity ADBE US Equity
# IBM UN Equity CSCO US Equity
# IBM UN Equity ANET US Equity
# IBM UN Equity BHE US Equity
# IBM UN Equity 2317 TT Equity
# IBM UN Equity 6503 JP Equity
# IBM UN Equity NVDA US Equity
# IBM UN Equity DLR US Equity
# IBM UN Equity 000660 KS Equity
# IBM UN Equity VOW GR Equity
# IBM UN Equity CA FP Equity
# IBM UN Equity WMT US Equity
# IBM UN Equity AD NA Equity
# IBM UN Equity RTX US Equity
# IBM UN Equity KR US Equity
# IBM UN Equity ARW US Equity
# IBM UN Equity 7203 JP Equity
# IBM UN Equity 034730 KS Equity
# IBM UN Equity WBA US Equity
# IBM UN Equity BRK/A US Equity
# IBM UN Equity AIR FP Equity
# IBM UN Equity ABC US Equity
# IBM UN Equity 7267 JP Equity
# IBM UN Equity LMT US Equity
# IBM UN Equity MPC US Equity
# IBM UN Equity 6752 JP Equity
# IBM UN Equity MAERSKB DC Equity
# IBM UN Equity 992 HK Equity
# IBM UN Equity T US Equity
# IIVI UW Equity
# IIVI UW Equity ES US Equity
# IIVI UW Equity DM US Equity
# IIVI UW Equity BESI NA Equity
# IIVI UW Equity DUK US Equity
# IIVI UW Equity 3105 TT Equity
# IIVI UW Equity EXC US Equity
# IIVI UW Equity GE US Equity
# IIVI UW Equity PPL US Equity
# IIVI UW Equity KEYS US Equity
# IIVI UW Equity KLAC US Equity
# IIVI UW Equity STM FP Equity
# IIVI UW Equity PEG US Equity
# IIVI UW Equity EIX US Equity
# IIVI UW Equity FN US Equity
# IIVI UW Equity PNM US Equity
# IIVI UW Equity VECO US Equity
# IIVI UW Equity IBE SM Equity
# IIVI UW Equity QRVO US Equity
# IIVI UW Equity NPTN US Equity
# IIVI UW Equity PCG US Equity
# IIVI UW Equity ASML NA Equity
# IIVI UW Equity IFX GR Equity
# IIVI UW Equity 000938 CH Equity
# IIVI UW Equity GOOGL US Equity
# IIVI UW Equity F US Equity
# IIVI UW Equity NOKIA FH Equity
# IIVI UW Equity DELL US Equity
# IIVI UW Equity 6702 JP Equity
# IIVI UW Equity 600498 CH Equity
# IIVI UW Equity DE US Equity
# IIVI UW Equity AAPL US Equity
# IIVI UW Equity 5802 JP Equity
# IIVI UW Equity STM FP Equity
# IIVI UW Equity CAT US Equity
# IIVI UW Equity CSCO US Equity
# IIVI UW Equity 000063 CH Equity
# IIVI UW Equity NDA GR Equity
# IIVI UW Equity 066570 KS Equity
# IIVI UW Equity 700 HK Equity
# IIVI UW Equity 6701 JP Equity
# INTC UW Equity
# INTC UW Equity MU US Equity
# INTC UW Equity FDX US Equity
# INTC UW Equity 2330 TT Equity
# INTC UW Equity 6967 JP Equity
# INTC UW Equity ASML NA Equity
# INTC UW Equity 7731 JP Equity
# INTC UW Equity 6857 JP Equity
# INTC UW Equity 000660 KS Equity
# INTC UW Equity 2317 TT Equity
# INTC UW Equity AMAT US Equity
# INTC UW Equity 2382 TT Equity
# INTC UW Equity 4062 JP Equity
# INTC UW Equity 7735 JP Equity
# INTC UW Equity GLEN LN Equity
# INTC UW Equity AMKR US Equity
# INTC UW Equity GLW US Equity
# INTC UW Equity 4063 JP Equity
# INTC UW Equity KLAC US Equity
# INTC UW Equity LRCX US Equity
# INTC UW Equity 8035 JP Equity
# INTC UW Equity 2353 TT Equity
# INTC UW Equity 000977 CH Equity
# INTC UW Equity AAPL US Equity
# INTC UW Equity VOD LN Equity
# INTC UW Equity HPQ US Equity
# INTC UW Equity 900938 CH Equity
# INTC UW Equity HPE US Equity
# INTC UW Equity META US Equity
# INTC UW Equity GOOGL US Equity
# INTC UW Equity DELL US Equity
# INTC UW Equity 992 HK Equity
# INTC UW Equity AVT US Equity
# INTC UW Equity 3702 TT Equity
# INTC UW Equity JD US Equity
# INTC UW Equity 2357 TT Equity
# INTC UW Equity TEF SM Equity
# INTC UW Equity AMZN US Equity
# INTC UW Equity SNX US Equity
# INTC UW Equity ARW US Equity
# INTC UW Equity MSFT US Equity
# INTU UW Equity
# INTU UW Equity MA US Equity
# INTU UW Equity META US Equity
# INTU UW Equity GDOT US Equity
# INTU UW Equity EB US Equity
# INTU UW Equity 664088Z US Equity
# INTU UW Equity OKTA US Equity
# INTU UW Equity BNFT US Equity
# INTU UW Equity TEAM US Equity
# INTU UW Equity SPLK US Equity
# INTU UW Equity SEND US Equity
# INTU UW Equity BTG GR Equity
# INTU UW Equity SRE US Equity
# INTU UW Equity 6944761Z SP Equity
# INTU UW Equity SPSC US Equity
# INTU UW Equity PNM US Equity
# INTU UW Equity ADBE US Equity
# INTU UW Equity BRK/A US Equity
# INTU UW Equity SWCH US Equity
# INTU UW Equity HPE US Equity
# INTU UW Equity MCRO LN Equity
# INTU UW Equity CNXN US Equity
# INTU UW Equity TNET US Equity
# INTU UW Equity AAPL US Equity
# INTU UW Equity BBY US Equity
# INTU UW Equity 8233297Z US Equity
# INTU UW Equity NSIT US Equity
# INTU UW Equity ACIW US Equity
# INTU UW Equity NEGG US Equity
# INTU UW Equity GOOGL US Equity
# IPGP UW Equity
# IPGP UW Equity GHH LN Equity
# IPGP UW Equity SRE US Equity
# IPGP UW Equity PCG US Equity
# IPGP UW Equity ES US Equity
# IPGP UW Equity UTL US Equity
# IPGP UW Equity VECO US Equity
# IPGP UW Equity 327260 KS Equity
# IPGP UW Equity NG/ LN Equity
# IPGP UW Equity 002222 CH Equity
# IPGP UW Equity SO US Equity
# IPGP UW Equity PNM US Equity
# IPGP UW Equity NEE US Equity
# IPGP UW Equity DUK US Equity
# IPGP UW Equity AQN CN Equity
# IPGP UW Equity DTE US Equity
# IPGP UW Equity XEL US Equity
# IPGP UW Equity BIOL US Equity
# IPGP UW Equity 300220 CH Equity
# IPGP UW Equity GE US Equity
# IPGP UW Equity GM US Equity
# IPGP UW Equity 002008 CH Equity
# IPGP UW Equity LMT US Equity
# IPGP UW Equity PRI IM Equity
# IPGP UW Equity KLAC US Equity
# IPGP UW Equity BA US Equity
# IPGP UW Equity AM3D GR Equity
# IPGP UW Equity ESI FP Equity
# IPGP UW Equity F US Equity
# IPGP UW Equity ATEC US Equity
# IPGP UW Equity 7011 JP Equity
# IPGP UW Equity BMW GR Equity
# IPGP UW Equity 1262316D RU Equity
# IPGP UW Equity VOW GR Equity
# IPGP UW Equity 002559 CH Equity
# IPGP UW Equity VECO US Equity
# IPGP UW Equity 6503 JP Equity
# IPGP UW Equity BYS SW Equity
# IT UN Equity
# IT UN Equity WLN FP Equity
# IT UN Equity EXC US Equity
# IT UN Equity ES US Equity
# IT UN Equity VNO US Equity
# IT UN Equity 0834326D US Equity
# IT UN Equity LANZ CH Equity
# IT UN Equity 1972 HK Equity
# IT UN Equity SAP GR Equity
# IT UN Equity 000977 CH Equity
# IT UN Equity IBE SM Equity
# IT UN Equity BABA US Equity
# IT UN Equity 600718 CH Equity
# IT UN Equity JBGS US Equity
# IT UN Equity ALFRE FP Equity
# IT UN Equity NEE US Equity
# IT UN Equity PDM US Equity
# IT UN Equity RMCS IN Equity
# IT UN Equity FAA GR Equity
# IT UN Equity CRC US Equity
# IT UN Equity ITX SM Equity
# IT UN Equity 1515 TT Equity
# IT UN Equity AWTC MK Equity
# IT UN Equity 2480 TT Equity
# IT UN Equity 3352Z US Equity
# JKHY UW Equity
# JKHY UW Equity 7751 JP Equity
# JKHY UW Equity IBM US Equity
# JKHY UW Equity 142859Z IM Equity
# JKHY UW Equity 992 HK Equity
# JKHY UW Equity SAP GR Equity
# JKHY UW Equity DGCKZ JP Equity
# JKHY UW Equity DELL US Equity
# JKHY UW Equity HPQ US Equity
# JKHY UW Equity PRGS US Equity
# JKHY UW Equity MSFT US Equity
# JKHY UW Equity MA US Equity
# JKHY UW Equity ORCL US Equity
# JKHY UW Equity ACIW US Equity
# JKHY UW Equity 6724 JP Equity
# JKHY UW Equity MA US Equity
# JKHY UW Equity ACIW US Equity
# JKHY UW Equity 283936Z US Equity
# JKHY UW Equity 7350074Z US Equity
# JKHY UW Equity 2137412Z US Equity
# JKHY UW Equity 0194322D US Equity
# JKHY UW Equity OLB US Equity
# JKHY UW Equity NUE US Equity
# JKHY UW Equity 1786285D US Equity
# JKHY UW Equity 4165 JP Equity
# JKHY UW Equity 467600Z US Equity
# JNPR UN Equity
# JNPR UN Equity IFX GR Equity
# JNPR UN Equity AVGO US Equity
# JNPR UN Equity 002851 CH Equity
# JNPR UN Equity MEI US Equity
# JNPR UN Equity BELFA US Equity
# JNPR UN Equity CTS US Equity
# JNPR UN Equity CLS CN Equity
# JNPR UN Equity INTC US Equity
# JNPR UN Equity BABA US Equity
# JNPR UN Equity LSCC US Equity
# JNPR UN Equity MXL US Equity
# JNPR UN Equity KEYS US Equity
# JNPR UN Equity FLEX US Equity
# JNPR UN Equity CDNS US Equity
# JNPR UN Equity MU US Equity
# JNPR UN Equity ORCL US Equity
# JNPR UN Equity TSEM IT Equity
# JNPR UN Equity TTMI US Equity
# JNPR UN Equity 3380 TT Equity
# JNPR UN Equity 2345 TT Equity
# JNPR UN Equity RTX US Equity
# JNPR UN Equity 6701 JP Equity
# JNPR UN Equity DTE GR Equity
# JNPR UN Equity ORA FP Equity
# JNPR UN Equity MSFT US Equity
# JNPR UN Equity T US Equity
# JNPR UN Equity GOOGL US Equity
# JNPR UN Equity META US Equity
# JNPR UN Equity CMCSA US Equity
# JNPR UN Equity AMZN US Equity
# JNPR UN Equity SNX US Equity
# JNPR UN Equity 2347 TT Equity
# JNPR UN Equity LDOS US Equity
# JNPR UN Equity 9432 JP Equity
# JNPR UN Equity GD US Equity
# JNPR UN Equity LMT US Equity
# JNPR UN Equity 6501 JP Equity
# JNPR UN Equity VZ US Equity
# JNPR UN Equity 6702 JP Equity
# JNPR UN Equity 9984 JP Equity
# KEYS UN Equity
# KEYS UN Equity AEP US Equity
# KEYS UN Equity 9719 JP Equity
# KEYS UN Equity PNM US Equity
# KEYS UN Equity INTT US Equity
# KEYS UN Equity EIX US Equity
# KEYS UN Equity APH US Equity
# KEYS UN Equity PCTI US Equity
# KEYS UN Equity TTMI US Equity
# KEYS UN Equity BRK/A US Equity
# KEYS UN Equity MKSI US Equity
# KEYS UN Equity EXC US Equity
# KEYS UN Equity DUK US Equity
# KEYS UN Equity ES US Equity
# KEYS UN Equity MTSI US Equity
# KEYS UN Equity PPL US Equity
# KEYS UN Equity PCG US Equity
# KEYS UN Equity PNW US Equity
# KEYS UN Equity JBL US Equity
# KEYS UN Equity SO US Equity
# KEYS UN Equity 9503 JP Equity
# KEYS UN Equity SNX US Equity
# KEYS UN Equity 066570 KS Equity
# KEYS UN Equity 2454 TT Equity
# KEYS UN Equity CSCO US Equity
# KEYS UN Equity MBG GR Equity
# KEYS UN Equity BA US Equity
# KEYS UN Equity INTC US Equity
# KEYS UN Equity GOOGL US Equity
# KEYS UN Equity RTX US Equity
# KEYS UN Equity LMT US Equity
# KEYS UN Equity NVDA US Equity
# KEYS UN Equity 7203 JP Equity
# KEYS UN Equity AIR FP Equity
# KEYS UN Equity LDO IM Equity
# KEYS UN Equity AVGO US Equity
# KEYS UN Equity QCOM US Equity
# KEYS UN Equity 005930 KS Equity
# KEYS UN Equity META US Equity
# KEYS UN Equity NOKIA FH Equity
# KEYS UN Equity 941 HK Equity
# KLAC UW Equity
# KLAC UW Equity LITE US Equity
# KLAC UW Equity MKSI US Equity
# KLAC UW Equity CYBE US Equity
# KLAC UW Equity PLXS US Equity
# KLAC UW Equity UCTT US Equity
# KLAC UW Equity VACN SW Equity
# KLAC UW Equity 1972 HK Equity
# KLAC UW Equity PCG US Equity
# KLAC UW Equity IIVI US Equity
# KLAC UW Equity AZTA US Equity
# KLAC UW Equity HPE US Equity
# KLAC UW Equity PPL US Equity
# KLAC UW Equity SSREIT SP Equity
# KLAC UW Equity VPG US Equity
# KLAC UW Equity ES US Equity
# KLAC UW Equity IPGP US Equity
# KLAC UW Equity 2303 TT Equity
# ...
# SNPS UW Equity
# SNPS UW Equity AMD US Equity
# SNPS UW Equity ADBE US Equity
# SNPS UW Equity MSFT US Equity
# SNPS UW Equity KRC US Equity
# SNPS UW Equity 002362 CH Equity
# SNPS UW Equity RMBS US Equity
# SNPS UW Equity IZMO IN Equity
# SNPS UW Equity 002635 CH Equity
# SNPS UW Equity POR US Equity
# SNPS UW Equity PCG US Equity
# SNPS UW Equity 000660 KS Equity
# SNPS UW Equity BABA US Equity
# SNPS UW Equity ANSS US Equity
# SNPS UW Equity 6423 TT Equity
# SNPS UW Equity AMZN US Equity
# SNPS UW Equity XPER US Equity
# SNPS UW Equity PTC US Equity
# SNPS UW Equity 9880 JP Equity
# SNPS UW Equity STL LN Equity
# SNPS UW Equity GOOGL US Equity
# SNPS UW Equity GFS US Equity
# SNPS UW Equity 000670 CH Equity
# SNPS UW Equity ARW US Equity
# SNPS UW Equity 3443 TT Equity
# SNPS UW Equity 0219682Z US Equity
# SNPS UW Equity 688256 CH Equity
# SNPS UW Equity ANSS US Equity
# SNPS UW Equity 4312 JP Equity
# SNPS UW Equity 2454 TT Equity
# SNPS UW Equity CON GR Equity
# SNPS UW Equity INTC US Equity
# SNPS UW Equity 8299 TT Equity
# SNPS UW Equity 6198 TT Equity
# SNPS UW Equity 1571354D LN Equity
# SNPS UW Equity 0053963D US Equity
# SNPS UW Equity 3352Z US Equity
# SNPS UW Equity AMBA US Equity
# SNPS UW Equity 300613 CH Equity
# SNPS UW Equity 6723 JP Equity
# SNPS UW Equity 8054 TT Equity
# STX UW Equity
# STX UW Equity VSH US Equity
# STX UW Equity 043590 KS Equity
# STX UW Equity ON US Equity
# STX UW Equity 2312 TT Equity
# STX UW Equity TER US Equity
# STX UW Equity 5991 JP Equity
# STX UW Equity 002635 CH Equity
# STX UW Equity 1586 TT Equity
# STX UW Equity 4551 TT Equity
# STX UW Equity 012450 KS Equity
# STX UW Equity 3060 TT Equity
# STX UW Equity 025100 KF Equity
# STX UW Equity AVGO US Equity
# STX UW Equity 3305 TT Equity
# STX UW Equity VECO US Equity
# STX UW Equity 2069 TT Equity
# STX UW Equity 4545 TT Equity
# STX UW Equity STM FP Equity
# STX UW Equity IVAC US Equity
# STX UW Equity 140860 KS Equity
# STX UW Equity 992 HK Equity
# STX UW Equity SNX US Equity
# STX UW Equity AMZN US Equity
# STX UW Equity 900938 CH Equity
# STX UW Equity 601138 CH Equity
# STX UW Equity 2357 TT Equity
# STX UW Equity ARW US Equity
# STX UW Equity CSCO US Equity
# STX UW Equity 2382 TT Equity
# STX UW Equity JD US Equity
# STX UW Equity HPQ US Equity
# STX UW Equity META US Equity
# STX UW Equity 2353 TT Equity
# STX UW Equity WMT US Equity
# STX UW Equity MSFT US Equity
# STX UW Equity 000977 CH Equity
# STX UW Equity KMCACZ CH Equity
# STX UW Equity 6701 JP Equity
# STX UW Equity HPE US Equity
# STX UW Equity DELL US Equity
# SWKS UW Equity
# SWKS UW Equity 2449 TT Equity
# SWKS UW Equity 042700 KS Equity
# SWKS UW Equity BESI NA Equity
# SWKS UW Equity KLAC US Equity
# SWKS UW Equity 7609 JP Equity
# SWKS UW Equity 217190 KS Equity
# SWKS UW Equity 009150 KS Equity
# SWKS UW Equity 2454 TT Equity
# SWKS UW Equity 8086 TT Equity
# SWKS UW Equity COHU US Equity
# SWKS UW Equity 353200 KS Equity
# SWKS UW Equity KEYS US Equity
# SWKS UW Equity 3105 TT Equity
# SWKS UW Equity GFS US Equity
# SWKS UW Equity 6387 JP Equity
# SWKS UW Equity 011070 KS Equity
# SWKS UW Equity KLIC US Equity
# SWKS UW Equity 008060 KS Equity
# SWKS UW Equity 2478 TT Equity
# SWKS UW Equity TSEM IT Equity
# SWKS UW Equity GE US Equity
# SWKS UW Equity 1810 HK Equity
# SWKS UW Equity MSFT US Equity
# SWKS UW Equity NOKIA FH Equity
# SWKS UW Equity ERICB SS Equity
# SWKS UW Equity NOC US Equity
# SWKS UW Equity 992 HK Equity
# SWKS UW Equity 2357 TT Equity
# SWKS UW Equity GOOGL US Equity
# SWKS UW Equity AVT US Equity
# SWKS UW Equity ARW US Equity
# SWKS UW Equity 005930 KS Equity
# SWKS UW Equity 2317 TT Equity
# SWKS UW Equity 3036 TT Equity
# SWKS UW Equity 3702 TT Equity
# SWKS UW Equity CSCO US Equity
# SWKS UW Equity RTX US Equity
# SWKS UW Equity KMCACZ CH Equity
# SWKS UW Equity AMZN US Equity
# SWKS UW Equity AAPL US Equity
# TDY UN Equity
# TDY UN Equity 0343287Z US Equity
# TDY UN Equity TSEM IT Equity
# TDY UN Equity ON US Equity
# TDY UN Equity HEI US Equity
# TDY UN Equity ETR US Equity
# TDY UN Equity ES US Equity
# TDY UN Equity D US Equity
# TDY UN Equity VIAV US Equity
# TDY UN Equity EMKR US Equity
# TDY UN Equity FTG CN Equity
# TDY UN Equity EIX US Equity
# TDY UN Equity FE US Equity
# TDY UN Equity NVDA US Equity
# TDY UN Equity AQN CN Equity
# TDY UN Equity EXC US Equity
# TDY UN Equity CNP US Equity
# TDY UN Equity DUK US Equity
# TDY UN Equity AMBA US Equity
# TDY UN Equity CW US Equity
# TDY UN Equity EMBASSY IN Equity
# TDY UN Equity 6752 JP Equity
# TDY UN Equity 079550 KS Equity
# TDY UN Equity BBY US Equity
# TDY UN Equity AIR FP Equity
# TDY UN Equity LTM CI Equity
# TDY UN Equity HON US Equity
# TDY UN Equity CNXN US Equity
# TDY UN Equity GD US Equity
# TDY UN Equity WCC US Equity
# TDY UN Equity LHX US Equity
# TDY UN Equity HO FP Equity
# TDY UN Equity HD US Equity
# TDY UN Equity NOC US Equity
# TDY UN Equity 3352Z US Equity
# TDY UN Equity BA US Equity
# TDY UN Equity VSAT US Equity
# TDY UN Equity LDO IM Equity
# TDY UN Equity LMT US Equity
# TDY UN Equity RTX US Equity
# TDY UN Equity BA/ LN Equity
# TEL UN Equity
# TEL UN Equity ADBE US Equity
# TEL UN Equity CAP FP Equity
# TEL UN Equity LITE US Equity
# TEL UN Equity 300240 CH Equity
# TEL UN Equity NNBR US Equity
# TEL UN Equity CTS US Equity
# TEL UN Equity 6279 TT Equity
# TEL UN Equity AVGO US Equity
# TEL UN Equity 4720 TT Equity
# TEL UN Equity 600255 CH Equity
# TEL UN Equity MXL US Equity
# TEL UN Equity 2476 TT Equity
# TEL UN Equity 107640 KS Equity
# TEL UN Equity 049070 KS Equity
# TEL UN Equity MCHP US Equity
# TEL UN Equity 032940 KS Equity
# TEL UN Equity 1964632D US Equity
# TEL UN Equity 6272 TT Equity
# TEL UN Equity 603045 CH Equity
# TEL UN Equity 6258 JP Equity
# TEL UN Equity 019180 KS Equity
# TEL UN Equity BA US Equity
# TEL UN Equity 000062 CH Equity
# TEL UN Equity 0751831D US Equity
# TEL UN Equity CNXN US Equity
# TEL UN Equity ARW US Equity
# TEL UN Equity PCAR US Equity
# TEL UN Equity MSFT US Equity
# TEL UN Equity 066570 KS Equity
# TEL UN Equity 000977 CH Equity
# TEL UN Equity 7537 JP Equity
# TEL UN Equity 000651 CH Equity
# TEL UN Equity 002242 CH Equity
# TEL UN Equity AVT US Equity
# TEL UN Equity 073070 KS Equity
# TEL UN Equity 049070 KS Equity
# TEL UN Equity 000063 CH Equity
# TEL UN Equity 005930 KS Equity
# TEL UN Equity AIR FP Equity
# TEL UN Equity BBD/B CN Equity
# TER UW Equity
# TER UW Equity INTT US Equity
# TER UW Equity 131290 KS Equity
# TER UW Equity CDNS US Equity
# TER UW Equity ES US Equity
# TER UW Equity AES US Equity
# TER UW Equity PCG US Equity
# TER UW Equity B US Equity
# TER UW Equity NVDA US Equity
# TER UW Equity EXC US Equity
# TER UW Equity GVTL SP Equity
# TER UW Equity NG/ LN Equity
# TER UW Equity FLEX US Equity
# TER UW Equity TTMI US Equity
# TER UW Equity KXS CN Equity
# TER UW Equity AMD US Equity
# TER UW Equity ADI US Equity
# TER UW Equity 6407 JP Equity
# TER UW Equity EIX US Equity
# TER UW Equity PLXS US Equity
# TER UW Equity VPG US Equity
# TER UW Equity WDC US Equity
# TER UW Equity QCOM US Equity
# TER UW Equity ADI US Equity
# TER UW Equity AMKR US Equity
# TER UW Equity LEA US Equity
# TER UW Equity 2330 TT Equity
# TER UW Equity MU US Equity
# TER UW Equity 7201 JP Equity
# TER UW Equity 3711 TT Equity
# TER UW Equity IFX GR Equity
# TER UW Equity STX US Equity
# TER UW Equity 042380 KF Equity
# TER UW Equity 8150 TT Equity
# TER UW Equity MCHP US Equity
# TER UW Equity CON GR Equity
# TER UW Equity 6239 TT Equity
# TER UW Equity 005930 KS Equity
# TER UW Equity 2449 TT Equity
# TER UW Equity NXPI US Equity
# TER UW Equity TXN US Equity
# TRMB UW Equity
# TRMB UW Equity DDOG US Equity
# TRMB UW Equity 0133437D US Equity
# TRMB UW Equity EGHT US Equity
# TRMB UW Equity MXL US Equity
# TRMB UW Equity 3023 TT Equity
# TRMB UW Equity HEI US Equity
# TRMB UW Equity 0060621Z US Equity
# TRMB UW Equity PTC US Equity
# TRMB UW Equity BHE US Equity
# TRMB UW Equity D US Equity
# TRMB UW Equity AVD US Equity
# TRMB UW Equity ACCB BB Equity
# TRMB UW Equity FLEX US Equity
# TRMB UW Equity CAMP US Equity
# TRMB UW Equity 002383 CH Equity
# TRMB UW Equity DGII US Equity
# TRMB UW Equity DUK US Equity
# TRMB UW Equity AES US Equity
# TRMB UW Equity JBL US Equity
# TRMB UW Equity BRK/A US Equity
# TRMB UW Equity 603528 CH Equity
# TRMB UW Equity 5067317Z US Equity
# TRMB UW Equity CAT US Equity
# TRMB UW Equity QCOM US Equity
# TRMB UW Equity DE US Equity
# TRMB UW Equity 4131589Z US Equity
# TRMB UW Equity SNX US Equity
# TRMB UW Equity 4513291Z NO Equity
# TRMB UW Equity 0494901D SW Equity
# TRMB UW Equity PCAR US Equity
# TRMB UW Equity FERREYC1 PE Equity
# TRMB UW Equity AHT LN Equity
# TRMB UW Equity 3352Z US Equity
# TRMB UW Equity CMI US Equity
# TRMB UW Equity ARKA IJ Equity
# TRMB UW Equity CNHI US Equity
# TRMB UW Equity CNXN US Equity
# TRMB UW Equity 0089886Z SW Equity
# TRMB UW Equity 7731 JP Equity
# TRMB UW Equity 9894609Z US Equity
# TSM UN Equity
# TSM UN Equity ASML NA Equity
# TSM UN Equity AI FP Equity
# TSM UN Equity 4186 JP Equity
# TSM UN Equity 6361 JP Equity
# TSM UN Equity AMAT US Equity
# TSM UN Equity WAF GR Equity
# TSM UN Equity 6488 TT Equity
# TSM UN Equity LRCX US Equity
# TSM UN Equity KLAC US Equity
# TSM UN Equity 5201 JP Equity
# TSM UN Equity 7731 JP Equity
# TSM UN Equity 4063 JP Equity
# TSM UN Equity TER US Equity
# TSM UN Equity DOW US Equity
# TSM UN Equity 6146 JP Equity
# TSM UN Equity 4005 JP Equity
# TSM UN Equity ENTG US Equity
# TSM UN Equity 7735 JP Equity
# TSM UN Equity AMKR US Equity
# TSM UN Equity 8035 JP Equity
# TSM UN Equity QCOM US Equity
# TSM UN Equity CRUS US Equity
# TSM UN Equity NVDA US Equity
# TSM UN Equity 2454 TT Equity
# TSM UN Equity ADI US Equity
# TSM UN Equity MRVL US Equity
# TSM UN Equity HIMX US Equity
# TSM UN Equity AAPL US Equity
# TSM UN Equity ON US Equity
# TSM UN Equity AMD US Equity
# TSM UN Equity STM FP Equity
# TSM UN Equity TXN US Equity
# TSM UN Equity INTC US Equity
# TSM UN Equity 6723 JP Equity
# TSM UN Equity IFX GR Equity
# TSM UN Equity 8299 TT Equity
# TSM UN Equity NXPI US Equity
# TSM UN Equity AMS SW Equity
# TSM UN Equity AVGO US Equity
# TSM UN Equity 6758 JP Equity
# TXN UW Equity
# TXN UW Equity 600584 CH Equity
# TXN UW Equity 2330 TT Equity
# TXN UW Equity TER US Equity
# TXN UW Equity 000990 KS Equity
# TXN UW Equity 6488 TT Equity
# TXN UW Equity 3711 TT Equity
# TXN UW Equity ATCOA SS Equity
# TXN UW Equity 4186 JP Equity
# TXN UW Equity KLAC US Equity
# TXN UW Equity KLIC US Equity
# TXN UW Equity COHU US Equity
# TXN UW Equity 8035 JP Equity
# TXN UW Equity 3436 JP Equity
# TXN UW Equity AMKR US Equity
# TXN UW Equity ADBE US Equity
# TXN UW Equity CCMP US Equity
# TXN UW Equity MU US Equity
# TXN UW Equity WAF GR Equity
# TXN UW Equity 2303 TT Equity
# TXN UW Equity 002156 CH Equity
# TXN UW Equity VC US Equity
# TXN UW Equity 7212 JP Equity
# TXN UW Equity AAPL US Equity
# TXN UW Equity ARW US Equity
# TXN UW Equity 3323 TT Equity
# TXN UW Equity 992 HK Equity
# TXN UW Equity AVT US Equity
# TXN UW Equity 2760 JP Equity
# TXN UW Equity WLN FP Equity
# TXN UW Equity MSFT US Equity
# TXN UW Equity HPQ US Equity
# TXN UW Equity 8141 JP Equity
# TXN UW Equity 2464 TT Equity
# TXN UW Equity 2360 TT Equity
# TXN UW Equity 3036 TT Equity
# TXN UW Equity 3702 TT Equity
# TXN UW Equity 300184 CH Equity
# TXN UW Equity CEC GR Equity
# TXN UW Equity 3132 JP Equity
# TXN UW Equity 3105 JP Equity
# TYL UN Equity
# TYL UN Equity ACIW US Equity
# TYL UN Equity MRC CN Equity
# TYL UN Equity AMZN US Equity
# TYL UN Equity 3352Z US Equity
# TYL UN Equity 8762MF US Equity
# TYL UN Equity STOOK1 US Equity
# TYL UN Equity 9375MF US Equity
# TYL UN Equity 0891420D US Equity
# TYL UN Equity STOHI1 US Equity
# TYL UN Equity 8467MF US Equity
# TYL UN Equity STODE1 US Equity
# TYL UN Equity STOCO1 US Equity
# TYL UN Equity STOAR1 US Equity
# TYL UN Equity 0220114Z US Equity
# TYL UN Equity 0191294Z US Equity
# TYL UN Equity 10169MF US Equity
# TYL UN Equity 1013189D US Equity
# TYL UN Equity STOMS1 US Equity
# TYL UN Equity 7662Z US Equity
# TYL UN Equity 10197MF US Equity
# TYL UN Equity 4131721Z US Equity
# TYL UN Equity 3656MF US Equity
# V UN Equity
# V UN Equity ATO FP Equity
# V UN Equity DLO US Equity
# V UN Equity 002070 CH Equity
# V UN Equity DEC FP Equity
# V UN Equity AIM CN Equity
# V UN Equity FDC US Equity
# V UN Equity 8 HK Equity
# V UN Equity IATA IJ Equity
# V UN Equity 1972 HK Equity
# V UN Equity BCG IN Equity
# V UN Equity GBG LN Equity
# V UN Equity GDOT US Equity
# V UN Equity GPN US Equity
# V UN Equity KEYS US Equity
# V UN Equity AYX US Equity
# V UN Equity ADBE US Equity
# V UN Equity BLND LN Equity
# V UN Equity 6277 TT Equity
# V UN Equity APPS US Equity
# V UN Equity FINGB SS Equity
# V UN Equity EVCM US Equity
# V UN Equity FIS US Equity
# V UN Equity BIKE GR Equity
# V UN Equity 3086 JP Equity
# V UN Equity DESTQ US Equity
# V UN Equity DLO US Equity
# V UN Equity ACIW US Equity
# V UN Equity 4755 JP Equity
# V UN Equity GDOT US Equity
# V UN Equity ALHYP FP Equity
# V UN Equity COIN US Equity
# V UN Equity 1786115D NA Equity
# V UN Equity EVTC US Equity
# V UN Equity 259206Z SL Equity
# V UN Equity ARAMCO AB Equity
# V UN Equity CTLP US Equity
# V UN Equity CLA FP Equity
# V UN Equity EB US Equity
# V UN Equity EXPE US Equity
# V UN Equity EEFT US Equity
# VRSN UW Equity
# WDC UW Equity
# WDC UW Equity 6502 JP Equity
# WDC UW Equity 6594 JP Equity
# WDC UW Equity 000660 KS Equity
# WDC UW Equity APH US Equity
# WDC UW Equity VECO US Equity
# WDC UW Equity 4004 JP Equity
# WDC UW Equity STM FP Equity
# WDC UW Equity IVAC US Equity
# WDC UW Equity 6857 JP Equity
# WDC UW Equity 007810 KS Equity
# WDC UW Equity SIMO US Equity
# WDC UW Equity BESI NA Equity
# WDC UW Equity 089030 KS Equity
# WDC UW Equity 5985 JP Equity
# WDC UW Equity CCMP US Equity
# WDC UW Equity 6988 JP Equity
# WDC UW Equity AVGO US Equity
# WDC UW Equity TER US Equity
# WDC UW Equity ON US Equity
# WDC UW Equity CLS CN Equity
# WDC UW Equity 992 HK Equity
# WDC UW Equity ALSN SW Equity
# WDC UW Equity 000977 CH Equity
# WDC UW Equity AVGO US Equity
# WDC UW Equity SNX US Equity
# WDC UW Equity INTC US Equity
# WDC UW Equity AMD US Equity
# WDC UW Equity REDI IN Equity
# WDC UW Equity 2382 TT Equity
# WDC UW Equity AVT US Equity
# WDC UW Equity MSFT US Equity
# WDC UW Equity AAPL US Equity
# WDC UW Equity 2357 TT Equity
# WDC UW Equity ARW US Equity
# WDC UW Equity HPQ US Equity
# WDC UW Equity CSCO US Equity
# WDC UW Equity KMCACZ CH Equity
# WDC UW Equity HPE US Equity
# WDC UW Equity DELL US Equity
# WDC UW Equity 856 HK Equity
# WOLF UN Equity
# WOLF UN Equity 327260 KS Equity
# WOLF UN Equity SOI FP Equity
# WOLF UN Equity KLAC US Equity
# WOLF UN Equity 600703 CH Equity
# WOLF UN Equity PCG US Equity
# WOLF UN Equity EIX US Equity
# WOLF UN Equity DIOD US Equity
# WOLF UN Equity 0345599Z US Equity
# WOLF UN Equity COHU US Equity
# WOLF UN Equity AEP US Equity
# WOLF UN Equity 3714 TT Equity
# WOLF UN Equity 300346 CH Equity
# WOLF UN Equity DUK US Equity
# WOLF UN Equity WEC US Equity
# WOLF UN Equity 092190 KS Equity
# WOLF UN Equity ABBN SW Equity
# WOLF UN Equity 8053 JP Equity
# WOLF UN Equity 600066 CH Equity
# WOLF UN Equity GM US Equity
# WOLF UN Equity CTHR US Equity
# WOLF UN Equity 000062 CH Equity
# WOLF UN Equity STM FP Equity
# WOLF UN Equity BRK/A US Equity
# WOLF UN Equity AVT US Equity
# WOLF UN Equity ARW US Equity
# WOLF UN Equity GE US Equity
# WOLF UN Equity 218410 KS Equity
# WOLF UN Equity HD US Equity
# WOLF UN Equity BWA US Equity
# WOLF UN Equity 3702 TT Equity
# WOLF UN Equity IFX GR Equity
# WOLF UN Equity 000063 CH Equity
# WOLF UN Equity ON US Equity
# WOLF UN Equity 1003Z GR Equity
# WOLF UN Equity 1184 HK Equity
# ZBRA UW Equity
# ZBRA UW Equity 3023 TT Equity
# ZBRA UW Equity MCHP US Equity
# ZBRA UW Equity 103660 KS Equity
# ZBRA UW Equity 3545 TT Equity
# ZBRA UW Equity AEP US Equity
# ZBRA UW Equity BOSC US Equity
# ZBRA UW Equity 300151 CH Equity
# ZBRA UW Equity 002383 CH Equity
# ZBRA UW Equity ABST CN Equity
# ZBRA UW Equity NXPI US Equity
# ZBRA UW Equity 6146 TT Equity
# ZBRA UW Equity 093920 KS Equity
# ZBRA UW Equity PTC US Equity
# ZBRA UW Equity 040160 KS Equity
# ZBRA UW Equity 1534447D US Equity
# ZBRA UW Equity ADBE US Equity
# ZBRA UW Equity 066310 KS Equity
# ZBRA UW Equity 601231 CH Equity
# ZBRA UW Equity JBL US Equity
# ZBRA UW Equity DLG GR Equity
# ZBRA UW Equity LOW US Equity
# ZBRA UW Equity ARW US Equity
# ZBRA UW Equity NSIT US Equity
# ZBRA UW Equity XOM US Equity
# ZBRA UW Equity WBA US Equity
# ZBRA UW Equity SNX US Equity
# ZBRA UW Equity BC8 GR Equity
# ZBRA UW Equity CCC LN Equity
# ZBRA UW Equity TGT US Equity
# ZBRA UW Equity 861 HK Equity
# ZBRA UW Equity F US Equity
# ZBRA UW Equity 2414 TT Equity
# ZBRA UW Equity WMT US Equity
# ZBRA UW Equity SCSC US Equity
# ZBRA UW Equity COST US Equity
# ZBRA UW Equity HUN US Equity
# ZBRA UW Equity KR US Equity
# ZBRA UW Equity AAPL US Equity
# ZBRA UW Equity AMZN US Equity
# ZBRA UW Equity HD US Equity

# %%
len(list(G.edges()))
# Out:
# 0

# %% [markdown]
# ## 2. Keyword mapping with neo4j

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(r"C:\Users\p.peng\FinancialModelingPrep\data\tickers.db")
df = pd.read_sql("SELECT * FROM `all_company_profiles`", conn)

# %%
from keybert import KeyBERT
from typing import Tuple, Union, Optional, Set, Dict
model = KeyBERT()

STOPWORDS = ['company', 'holdings', 'limited', 'ltd',
    'group']

def extract_keywords(doc: str, 
    ngram_range: Tuple[int, int]=(1, 1),
    stop_words: Optional[Set]=STOPWORDS,
    **kwargs):
    return model.extract_keywords(doc, 
        keyphrase_ngram_range=ngram_range, 
        stop_words=stop_words, **kwargs)

# %%
help(model.extract_keywords)
# Out:
# Help on method extract_keywords in module keybert._model:
#
# extract_keywords(docs: Union[str, List[str]], candidates: List[str] = None, keyphrase_ngram_range: Tuple[int, int] = (1, 1), stop_words: Union[str, List[str]] = 'english', top_n: int = 5, min_df: int = 1, use_maxsum: bool = False, use_mmr: bool = False, diversity: float = 0.5, nr_candidates: int = 20, vectorizer: sklearn.feature_extraction.text.CountVectorizer = None, highlight: bool = False, seed_keywords: List[str] = None) -> Union[List[Tuple[str, float]], List[List[Tuple[str, float]]]] method of keybert._model.KeyBERT instance
#     Extract keywords and/or keyphrases
#
#     I would advise you to iterate over single documents as they
#     will need the least amount of memory. Even though this is slower,
#     you are not likely to run into memory errors.
#
#     There is an option to extract keywords for multiple documents
#     that is faster than extraction for multiple single documents.
#     However, this method assumes that you can keep the word embeddings
#     for all words in the vocabulary in memory which might be troublesome.
#     I would advise against using this option and simply iterating
#     over documents instead if you have limited hardware.
#
#     Arguments:
#         docs: The document(s) for which to extract keywords/keyphrases
#         candidates: Candidate keywords/keyphrases to use instead of extracting them from the document(s)
#         keyphrase_ngram_range: Length, in words, of the extracted keywords/keyphrases
#         stop_words: Stopwords to remove from the document
#         top_n: Return the top n keywords/keyphrases
#         min_df: Minimum document frequency of a word across all documents
#                 if keywords for multiple documents need to be extracted
#         use_maxsum: Whether to use Max Sum Similarity for the selection
#                     of keywords/keyphrases
#         use_mmr: Whether to use Maximal Marginal Relevance (MMR) for the
#                  selection of keywords/keyphrases
#         diversity: The diversity of the results between 0 and 1 if use_mmr
#                    is set to True
#         nr_candidates: The number of candidates to consider if use_maxsum is
#                        set to True
#         vectorizer: Pass in your own CountVectorizer from scikit-learn
#         highlight: Whether to print the document and highlight
#                    its keywords/keyphrases. NOTE: This does not work if
#                    multiple documents are passed.
#         seed_keywords: Seed keywords that may guide the extraction of keywords by
#                        steering the similarities towards the seeded keywords
#
#     Returns:
#         keywords: the top n keywords for a document with their respective distances
#                   to the input document

# %%
add_node('test', {'foundedIn':2014, 'activelyTrade': False})

# %%
"""OPTIONAL MATCH (n:Company {name:"test"})
RETURN n IS NOT NULL AS Predicate"""

# %%
driver = GraphDatabase.driver(uri=r"bolt://localhost:7687", 
        auth=("neo4j", input("password")))



res = node_exists(["Company"], {"name": "test1"})

# %%
print(add_relation(source={'label': 'Company', 'node_id': 'test_source'}, 
target={'label': 'Topic', 'node_id': 'test_target'}, 
relation_props={'type': 'mention'},
relation_type='related',
directed=True
    ))
# Out:
# MATCH
#         (a:Company),
#         (b:Topic)
#     WHERE a.node_id = test_source AND b.node_id = test_target
#     CREATE (a)-[r:related{{'type': 'mention'}}] ->(b)

# %%
from neo4j import GraphDatabase, Query
import nxneo4j as nnx
import datetime as dt
from typing import List, Dict, Union, Tuple, Iterable
import numpy as np

driver = GraphDatabase.driver(uri=r"bolt://localhost:7687", 
        auth=("neo4j", input("password")))
DEFAULT_NNX_CONFIG = {"node_label": "Company",
    "relationship_type": "related_to",
    }
G = nnx.Graph(driver, config=DEFAULT_NNX_CONFIG)


def node_exists(node_labels: Iterable[str], prop: Dict={}, 
    driver: GraphDatabase.driver=driver, verbose: bool=False):
    """check if node exists"""
    props = ", ".join([f"""{k}: \"{v}\"""" for k, v in prop.items() if type(v) in [str]] +\
            [f"{k}: {v}" for k, v in prop.items() 
            if type(v) in [float, int]] +\
            [f"{k}: {int(v)}" for k, v in prop.items() 
            if type(v) in [bool]])
    query = f"""OPTIONAL MATCH (n:{":".join(node_labels)}\u007b{props}\u007d)
    RETURN n IS NOT NULL AS Predicate"""
    if verbose: print(query)
    with driver.session() as session:
        result = session.run(Query(query)).single().value()
    return result

def add_node(node_id, metadata: Dict, 
    node_labels: Iterable[int]=['Company'], 
    match_field: Iterable[str]=['node_id'],
    driver=driver,
    verbose: bool=False):
    """add node to the graph if doesn't exist"""
    labels = ": ".join(node_labels)
    if not node_exists(node_labels=node_labels, 
    prop={k:v for k, v in metadata.items() if k in match_field},
    verbose=verbose):
        with driver.session() as session:
            props= ", ".join([f"""{k}: \"{v.replace("\"", "'")}\"""" 
            for k, v in metadata.items() if type(v) in [str]] +\
                [f"""node_id: \"{node_id}\""""] +\
                [f"{k}: {v}" for k, v in metadata.items() 
                if type(v) in [float, int]] +\
                [f"{k}: {int(v)}" for k, v in metadata.items() 
                if type(v) in [bool]])
            query = f"""CREATE (n:{labels} \u007b{props}\u007d)"""
            if verbose: print(query)
            session.run(Query(query))
        if verbose: print(f"added {node_id}")
    if verbose: print(f"failed to add {node_id}")

def add_relation(source: Dict, target: Dict, 
    relation_props: Dict,
    relation_type: str, 
    directed: bool=True, 
    driver: GraphDatabase.driver=driver,
    verbose: bool=False) -> None:
    """add relation to graph
    :param source: dictionary of the properties for the source, 
        must contain {'label': $label}
    :param target: dictionary of the properties for the target
    :paramm relation_type: type of the relation
    :param directed: boolean
    :param driver: GraphDatabase.driver object
    """
    a_cond = "AND ".join([f"a.{k} = '{v}'" 
        for k, v in source.items() if k != 'label']) # TODO - add
    b_cond = "AND ".join([f"b.{k} = '{v}'" 
        for k, v in target.items() if k != 'label'])
    arr = '->' if directed else '-'
    rel_props = ", ".join([f"""{k}: \"{v.replace("\"", "'")}\"""" for k, v in relation_props.items() if type(v) in [str]] +\
                [f"{k}: {v if v else ''}" for k, v in relation_props.items() 
                if type(v) in [float, int] ] +\
                [f"{k}: {int(v)}" for k, v in relation_props.items() 
                if type(v) in [bool]])
    query = f"""MATCH 
        (a:{source.get("label")}),
        (b:{target.get("label")})
    WHERE {a_cond} AND {b_cond}
    CREATE (a)-[r:{relation_type}\u007b{rel_props}\u007d]{arr}(b)
    """
    if verbose: print(query)
    with driver.session() as session:
        session.run(Query(query))

def add_ticker_with_keyword(ticker, 
    metadata: Dict, 
    max_ngram: int=3, 
    top_n=10, 
    diversity=0.9,
    driver: GraphDatabase.driver=driver,
    verbose: bool=True):
    """process a ticker and add that to the database"""
    metadata.update({'node_id': ticker})
    add_node(ticker, metadata=metadata, node_labels=['Company'], driver=driver,
        verbose=verbose)
    keywords = []
    for n in range(1, max_ngram+1):
        keywords += extract_keywords(metadata.get("description"), 
                ngram_range=(1, n), 
                top_n=top_n, diversity=diversity)

    for keyword, confidence in keywords:
        add_node(keyword, {'name': keyword, 
            'data_source': 'keyBERT extraction',
            'node_id': keyword}, 
            node_labels=['Topic'], driver=driver, verbose=verbose)
        # input()
        add_relation(source={'label': 'Company', 'node_id': ticker}, 
            target={'label': 'Topic', 'node_id': keyword}, 
            relation_props={'confidence': confidence,
                'weight': confidence},
            relation_type='mention',
            directed=True,
            verbose=verbose
                )
        # input()
    return keywords

# %%
node_exists(node_labels=['Topic'], prop={'node_id': 'resources'})
# Out:
# False

# %%
import logging
LOGFILE = "log/log.txt"
logging.basicConfig(filename=LOGFILE, level=logging.ERROR)
df = df.fillna('')
keywords = []
for _, row in df.iterrows():
    try:
        keywords += add_ticker_with_keyword(row.symbol, row.to_dict(), verbose=False)
    except Exception as e:
        logging.error(e)

# %%
keywords
# Out:
# [('shenzhen', 0.5195),
#  ('resources', 0.2999),
#  ('buildings', 0.2902),
#  ('building', 0.2868),
#  ('property', 0.2795),
#  ('development', 0.2652),
#  ('subsidiary', 0.2651),
#  ('properties', 0.237),
#  ('estate', 0.2314),
#  ('construction', 0.215),
#  ('shenzhen properties', 0.6845),
#  ('shenzhen investment', 0.5943),
#  ('of shenzhen', 0.5411),
#  ('shenzhen', 0.5195),
#  ('china shenzhen', 0.5),
#  ('shenzhen china', 0.4941),
#  ('in shenzhen', 0.4794),
#  ('resources development', 0.442),
#  ('properties resources', 0.416),
#  ('property management', 0.4146),
#  ('shenzhen properties resources', 0.7357),
#  ('shenzhen properties', 0.6845),
#  ('china shenzhen properties', 0.6823),
#  ('shenzhen investment co', 0.6244),
#  ('subsidiary of shenzhen', 0.6162),
#  ('of shenzhen investment', 0.6121),
#  ('based in shenzhen', 0.5967),
#  ('shenzhen investment', 0.5943),
#  ('of shenzhen', 0.5411),
#  ('shenzhen china shenzhen', 0.5254)]
